# %% [markdown]
# ### Goals
# - Convert CSS to SASS:
#     - Common values go into variables (e.g. colours)
#     - Common groups of styles (>= 2 styles) go into mixins
# - NLP to identify similar classes and ids
# - NLP to group selectors together and put them into seperate files
# - Minify

# %%
import os
import shutil
import re
import colorsys
import json
import numpy as np
import rcssmin
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
# original-dataset\\GlobalTVBC\\css\\23579edb1e12f906d2b83f522d1c27011dc1b1d8.css
with open("minified-dataset\\Facebook\\index_files\\1GsqYFnXaZQ.css", "rb") as file:
    css_text_test = file.read().decode(errors="replace")

# %%
def getSelectorStyleMap(styles):
    styles = np.array(styles.split("{"))
    styles = list(map(lambda selectorStyle: selectorStyle.split("}"), styles))
    styles = [j for sub in styles for j in sub] # empty string means end of an at rule
    
    selectorToStyle = {}
    mediaQuery = ""
    atRule = ""
    isSelector = True

    for i, cssComponent in enumerate(styles):
        if "@media" in cssComponent:
            mediaQuery = cssComponent
            continue
        elif "@" in atRule:
            atRule = cssComponent
            continue

        if isSelector:
            selectorToStyle[cssComponent] = None
            isSelector = False
        else:
            selectorToStyle[styles[i-1]] = {
                "style": list(map(lambda x: x.split(":"), cssComponent.split(";"))),
                "atRule": atRule,
                "mediaQuery": mediaQuery
            }
            isSelector = True

    return selectorToStyle

# %%
testStyleMap = getSelectorStyleMap(css_text_test)
testStyleMap
# Out:
# {'form': {'style': [['margin', '0'], ['padding', '0']],
#   'atRule': '',
#   'mediaQuery': ''},
#  'label': {'style': [['cursor', 'pointer'],
#    ['color', '#666'],
#    ['font-weight', 'bold'],
#    ['vertical-align', 'middle']],
#   'atRule': '',
#   'mediaQuery': ''},
#  'label input': {'style': [['font-weight', 'normal']],
#   'atRule': '',
#   'mediaQuery': ''},
#  'textarea,.inputtext,.inputpassword': {'style': [['border',
#     '1px solid #bdc7d8'],
#    ['margin', '0'],
#    ['padding', '3px'],
#    ['-webkit-appearance', 'none'],
#    ['-webkit-border-radius', '0']],
#   'atRule': '',
#   'mediaQuery': ''},
#  'textarea': {'style': [['max-width', '100%']],
#   'atRule': '',
#   'mediaQuery': ''},
#  'select': {'style': [['border', '1px solid #bdc7d8'], ['padding', '2px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.inputtext,.inputpassword': {'style': [['padding-bottom', '4px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.inputtext:invalid,.inputpassword:invalid': {'style': [['-webkit-box-shadow',
#     'none']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.inputradio': {'style': [['padding', '0'],
#    ['margin', '0 5px 0 0'],
#    ['vertical-align', 'middle']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.inputcheckbox': {'style': [['border', '0'], ['vertical-align', 'middle']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.inputbutton,.inputsubmit': {'style': [['border-style', 'solid'],
#    ['border-width', '1px'],
#    ['border-color', '#d9dfea #0e1f5b #0e1f5b #d9dfea'],
#    ['background-color', '#3b5998'],
#    ['color', '#fff'],
#    ['padding', '2px 15px 3px 15px'],
#    ['text-align', 'center']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.inputsubmit_disabled': {'style': [['background-color', '#999'],
#    ['border-bottom', '1px solid #000'],
#    ['border-right', '1px solid #666'],
#    ['color', '#fff']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.inputaux': {'style': [['background', '#f0f0f0'],
#    ['border-color', '#e7e7e7 #666 #666 #e7e7e7'],
#    ['color', '#000']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.inputaux_disabled': {'style': [['color', '#999']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.inputsearch': {'style': [['background',
#     '#fff url(/rsrc.php/v2/yV/r/IJYgcESal33.png) no-repeat left 4px'],
#    ['padding-left', '17px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  'body': {'style': [['background', '#fff'],
#    ['color', '#333'],
#    ['line-height', '1.28'],
#    ['margin', '0'],
#    ['padding', '0'],
#    ['text-align', 'left'],
#    ['direction', 'ltr'],
#    ['unicode-bidi', 'embed']],
#   'atRule': '',
#   'mediaQuery': ''},
#  'body,button,input,label,select,td,textarea': {'style': [['font-family',
#     "'lucida grande',tahoma,verdana,arial,sans-serif"],
#    ['font-size', '11px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  'h1,h2,h3,h4,h5,h6': {'style': [['font-size', '13px'],
#    ['color', '#333'],
#    ['margin', '0'],
#    ['padding', '0']],
#   'atRule': '',
#   'mediaQuery': ''},
#  'h1': {'style': [['font-size', '14px']], 'atRule': '', 'mediaQuery': ''},
#  'h4,h5,h6': {'style': [['font-size', '11px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  'p': {'style': [['margin', '1em 0']], 'atRule': '', 'mediaQuery': ''},
#  'a': {'style': [['color', '#3b5998'],
#    ['cursor', 'pointer'],
#    ['text-decoration', 'none']],
#   'atRule': '',
#   'mediaQuery': ''},
#  'button': {'style': [['margin', '0']], 'atRule': '', 'mediaQuery': ''},
#  'a:hover': {'style': [['text-decoration', 'underline']],
#   'atRule': '',
#   'mediaQuery': ''},
#  'img': {'style': [['border', '0']], 'atRule': '', 'mediaQuery': ''},
#  'td,td.label': {'style': [['text-align', 'left']],
#   'atRule': '',
#   'mediaQuery': ''},
#  'dd': {'style': [['color', '#000']], 'atRule': '', 'mediaQuery': ''},
#  'dt': {'style': [['color', '#777']], 'atRule': '', 'mediaQuery': ''},
#  'ul': {'style': [['list-style-type', 'none'],
#    ['margin', '0'],
#    ['padding', '0']],
#   'atRule': '',
#   'mediaQuery': ''},
#  'abbr': {'style': [['border-bottom', 'none']],
#   'atRule': '',
#   'mediaQuery': ''},
#  'hr': {'style': [['background', '#d9d9d9'],
#    ['border-width', '0'],
#    ['color', '#d9d9d9'],
#    ['height', '1px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.clearfix:after': {'style': [['clear', 'both'],
#    ['content', '"."'],
#    ['display', 'block'],
#    ['font-size', '0'],
#    ['height', '0'],
#    ['line-height', '0'],
#    ['visibility', 'hidden']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.clearfix': {'style': [['zoom', '1']], 'atRule': '', 'mediaQuery': ''},
#  '.datawrap': {'style': [['word-wrap', 'break-word']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.word_break': {'style': [['display', 'inline-block']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.ellipsis': {'style': [['overflow', 'hidden'],
#    ['text-overflow', 'ellipsis'],
#    ['white-space', 'nowrap']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.aero': {'style': [['opacity', '.5']], 'atRule': '', 'mediaQuery': ''},
#  '.column': {'style': [['float', 'left']], 'atRule': '', 'mediaQuery': ''},
#  '.center': {'style': [['margin-left', 'auto'], ['margin-right', 'auto']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '#facebook .hidden_elem': {'style': [['display', 'none!important']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '#facebook .invisible_elem': {'style': [['visibility', 'hidden']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '#facebook .accessible_elem': {'style': [['clip', 'rect(1px 1px 1px 1px)'],
#    ['clip', 'rect(1px,1px,1px,1px)'],
#    ['height', '1px'],
#    ['overflow', 'hidden'],
#    ['position', 'absolute'],
#    ['width', '1px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.direction_ltr': {'style': [['direction', 'ltr']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.direction_rtl': {'style': [['direction', 'rtl']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.text_align_ltr': {'style': [['text-align', 'left']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.text_align_rtl': {'style': [['text-align', 'right']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.DOMControl_placeholder': {'style': [['color', '#777']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.no_js .DOMControl_placeholder': {'style': [['color', '#000']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.fbx #pageFooter': {'style': [['margin', 'auto'], ['width', 'auto']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.navigationGrid': {'style': [['line-height', '20px'], ['width', '540px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.navigationGrid td': {'style': [['padding-right', '10px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.hasLeftCol #pageFooter': {'style': [['background-color', '#fff'],
#    ['clear', 'both'],
#    ['margin-left', '180px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '#pagefooter': {'style': [['border-top', '0']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '#pageFooter': {'style': [['color', '#737373'],
#    ['font-size', '11px'],
#    ['margin', '0 auto'],
#    ['width', '980px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '#pageFooter a': {'style': [['text-decoration', 'none'],
#    ['white-space', 'nowrap']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '#pageFooter a:last-child': {'style': [['margin-right', '0']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '#pageFooter a:hover': {'style': [['text-decoration', 'underline']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '#contentCurve': {'style': [['border-bottom', '1px solid #ccc'],
#    ['font-size', '1px'],
#    ['height', '8px'],
#    ['margin-bottom', '8px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.hasLeftCol #contentCurve': {'style': [['border', '1px solid #ccc'],
#    ['border-top', 'none'],
#    ['position', 'relative']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '#globalContainer': {'style': [['margin', '0 auto'],
#    ['position', 'relative'],
#    ['zoom', '1']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.fbx #globalContainer': {'style': [['width', '981px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.sidebarMode #globalContainer': {'style': [['padding-right', '205px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.sidebarMode .webkit #globalContainer .fixed_elem,.sidebarMode .webkit #globalContainer .fixed_always': {'style': [['margin',
#     'auto']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.fbx #tab_canvas>div': {'style': [['padding-top', '0']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.fb_content': {'style': [['padding-bottom', '20px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.fbx .fb_content': {'style': [['padding-bottom', '0']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.fixed_elem,.fixed_always': {'style': [['position', 'fixed!important']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.tinyViewport .fixed_elem': {'style': [['position', 'static!important']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._7ll': {'style': [['max-width', '350px'], ['min-width', '275px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._7lm': {'style': [['max-width', '275px']], 'atRule': '', 'mediaQuery': ''},
#  '._7ln': {'style': [['max-width', '240px']], 'atRule': '', 'mediaQuery': ''},
#  '._7lk': {'style': [['padding', '10px'], ['width', '275px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._7lu ._50hf,._7lu .pageByline': {'style': [['color', 'gray']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.FriendButton + ._7lp,.PageLikeButton + ._7lp,.FriendButton + ._7lq,.PageLikeButton + ._7lq,.FriendButton + ._7lr,.PageLikeButton + ._7lr,._7lp + ._7lr,._7lq + ._7lr': {'style': [['margin-left',
#     '4px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._7ls': {'style': [['margin-right', '10px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._7lt': {'style': [['width', '350px']], 'atRule': '', 'mediaQuery': ''},
#  '._7lt ._7lu': {'style': [['margin-top', '78px'], ['position', 'relative']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._5fyi': {'style': [['display', 'inline-block'], ['height', '20px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._5fyj': {'style': [['background-color', 'rgba(0,0,0,.5)'],
#    ['left', '0'],
#    ['padding', '5px 0 5px 5px'],
#    ['position', 'absolute'],
#    ['top', '0'],
#    ['width', '99%']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._5fyj .hovercardContent .fcg,._5fyk': {'style': [['color', '#fff'],
#    ['font-size', '11px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._53ij ._4g4y .uiBoxGray': {'style': [['border-color', '#d3d6db']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._4g4y': {'style': [['left', '-10px'],
#    ['margin-bottom', '-10px'],
#    ['margin-top', '10px'],
#    ['position', 'relative'],
#    ['width', '370px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.webkit ._7lt ._7lv': {'style': [['width', '10000px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._7lt ._7lv': {'style': [['padding-top', '46px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._7lt ._7ln a,._7lt .uiLinkSubtle,._7lt ._7lx ._50hf,._7lt .pageCityLink,._7lt ._7lx .pageByline,._7lt .fanCount': {'style': [['color',
#     '#fff']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._7lt ._50hf': {'style': [['margin-right', '4px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._7lt ._7ls': {'style': [['background', '#fff'],
#    ['background', 'rgba(0,0,0,.3)'],
#    ['-webkit-border-radius', '3px'],
#    ['-webkit-box-shadow', '0 1px 1px rgba(0,0,0,.07)'],
#    ['margin', '0 7px -4px -4px'],
#    ['padding', '1px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._7lt ._7lw': {'style': [['background-color', '#fff'],
#    ['border', '3px solid #fff'],
#    ['-webkit-border-radius', '2px'],
#    ['display', 'block'],
#    ['height', '100px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._7lt ._7lx': {'style': [['bottom', '3px'],
#    ['left', '120px'],
#    ['line-height', '1.2'],
#    ['max-width', '250px'],
#    ['min-height', '37px'],
#    ['position', 'absolute'],
#    ['z-index', '1']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._7lt ._7ln': {'style': [['max-width', '250px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._7ln a._5f2m': {'style': [['color', 'rgba(255,255,255,0.68)']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.sp_8jd5ay': {'style': [['background-image',
#     'url(/rsrc.php/v2/y2/r/k8z0py7VTRC.png)'],
#    ['background-size', 'auto'],
#    ['background-repeat', 'no-repeat'],
#    ['display', 'inline-block'],
#    ['height', '10px'],
#    ['width', '16px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.sx_69d0df': {'style': [['width', '14px'],
#    ['height', '14px'],
#    ['background-position', '-279px -175px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.sx_e2d837': {'style': [['height', '9px'],
#    ['background-position', '-261px -152px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.sx_19abc9': {'style': [['height', '9px'],
#    ['background-position', '-278px -152px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.sx_244e15': {'style': [['height', '9px'],
#    ['background-position', '-295px -152px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.sx_c6be4b': {'style': [['width', '9px'],
#    ['height', '16px'],
#    ['background-position', '-259px -175px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.sx_37a627': {'style': [['width', '9px'],
#    ['height', '16px'],
#    ['background-position', '-269px -175px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.sx_2d1a8a': {'style': [['height', '9px'],
#    ['background-position', '-312px -152px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.sx_b93a3b': {'style': [['height', '16px'],
#    ['background-position', '-191px -175px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.sx_1567db': {'style': [['width', '11px'],
#    ['background-position', '-215px -164px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.sx_fd6c2c': {'style': [['width', '9px'],
#    ['height', '5px'],
#    ['background-position', '-329px -152px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.sx_fda9f8': {'style': [['width', '5px'],
#    ['height', '3px'],
#    ['background-position', '-339px -152px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.sx_7964f7': {'style': [['height', '16px'],
#    ['background-position', '-208px -175px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.sx_7d697c': {'style': [['height', '16px'],
#    ['background-position', '-225px -175px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.sx_348cea': {'style': [['height', '16px'],
#    ['background-position', '-242px -175px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.sx_27a5d6': {'style': [['width', '22px'],
#    ['height', '11px'],
#    ['background-position', '-215px -152px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.sx_81073f': {'style': [['width', '11px'],
#    ['height', '22px'],
#    ['background-position', '-191px -152px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.sx_ac6b9e': {'style': [['width', '11px'],
#    ['height', '22px'],
#    ['background-position', '-203px -152px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.sx_5e6bce': {'style': [['width', '22px'],
#    ['height', '11px'],
#    ['background-position', '-238px -152px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.sx_9fca5c': {'style': [['width', '8px'],
#    ['height', '1px'],
#    ['background-position', '-206px -147px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.sx_70a683': {'style': [['width', '8px'],
#    ['height', '1px'],
#    ['background-position', '-215px -147px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.sx_b2ce33': {'style': [['width', '205px'],
#    ['height', '4px'],
#    ['background-position', '0 -147px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.sx_905c5d': {'style': [['width', '12px'],
#    ['height', '12px'],
#    ['background-position', '-294px -175px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.sx_b5e282': {'style': [['width', '12px'],
#    ['height', '12px'],
#    ['background-position', '-307px -175px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.sx_3465a0': {'style': [['width', '12px'],
#    ['height', '12px'],
#    ['background-position', '-320px -175px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.sx_8cc179': {'style': [['width', '12px'],
#    ['height', '12px'],
#    ['background-position', '-333px -175px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.sx_d2471f': {'style': [['width', '12px'],
#    ['height', '12px'],
#    ['background-position', '-346px -175px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.sx_ac63da': {'style': [['width', '10px'],
#    ['background-position', '-227px -164px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.sx_24263b': {'style': [['width', '10px'],
#    ['background-position', '-238px -164px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.sx_91625b': {'style': [['width', '10px'],
#    ['background-position', '-249px -164px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.sx_7d5182': {'style': [['width', '10px'],
#    ['background-position', '-260px -164px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.sx_fe523b': {'style': [['width', '10px'],
#    ['background-position', '-271px -164px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.sx_75b1aa': {'style': [['width', '500px'],
#    ['height', '48px'],
#    ['background-position', '0 0']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.sx_25b22b': {'style': [['width', '500px'],
#    ['height', '48px'],
#    ['background-position', '0 -49px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.sx_ca175b': {'style': [['width', '500px'],
#    ['height', '48px'],
#    ['background-position', '0 -98px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.sx_c100d2': {'style': [['width', '190px'],
#    ['height', '90px'],
#    ['background-position', '0 -152px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._42ft': {'style': [['cursor', 'pointer'],
#    ['display', 'inline-block'],
#    ['text-decoration', 'none'],
#    ['white-space', 'nowrap']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._42ft:hover': {'style': [['text-decoration', 'none']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._42ft + ._42ft': {'style': [['margin-left', '4px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._42fr,._42fs': {'style': [['cursor', 'default']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._53ij': {'style': [['background', '#fff'], ['position', 'relative']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._53io': {'style': [['overflow', 'hidden'], ['position', 'absolute']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._53ih ._53io': {'style': [['display', 'none']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._5f0v': {'style': [['outline', 'none']], 'atRule': '', 'mediaQuery': ''},
#  '._3oxt': {'style': [['outline', '1px dotted #3b5998'],
#    ['outline-color', 'invert']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.webkit ._3oxt': {'style': [['outline', '5px auto #5b9dd9']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.win.webkit ._3oxt': {'style': [['outline-color', '#e59700']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._8u': {'style': [['margin-top', '1px']], 'atRule': '', 'mediaQuery': ''},
#  '._8o,._8o .img': {'style': [['display', 'block']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._8r': {'style': [['margin-right', '5px'], ['margin-top', '-1px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._8s': {'style': [['margin-right', '8px']], 'atRule': '', 'mediaQuery': ''},
#  '._8t': {'style': [['margin-right', '10px']], 'atRule': '', 'mediaQuery': ''},
#  '.pop_container_advanced': {'style': [['background', 'rgba(82,82,82,0.7)'],
#    ['-webkit-border-radius', '8px'],
#    ['padding', '10px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.generic_dialog': {'style': [['height', '0'],
#    ['left', '0'],
#    ['overflow', 'visible'],
#    ['outline', 'none'],
#    ['position', 'fixed'],
#    ['top', '0'],
#    ['width', '100%'],
#    ['z-index', '200']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.generic_dialog_modal,.generic_dialog_fixed_overflow': {'style': [['background-color',
#     'rgba(252,252,252,.9)'],
#    ['height', '100%'],
#    ['z-index', '400']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.generic_dialog_fixed_overflow': {'style': [['overflow-x', 'auto'],
#    ['overflow-y', 'scroll']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.generic_dialog_fixed_overflow .generic_dialog_popup': {'style': [['height',
#     'auto'],
#    ['padding-bottom', '40px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.generic_dialog_overflow_mode body': {'style': [['overflow',
#     'hidden!important']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.generic_dialog_popup': {'style': [['height', '0'],
#    ['overflow', 'visible'],
#    ['width', '465px'],
#    ['margin', '0 auto']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.generic_dialog div.dialog_loading': {'style': [['background-color',
#     '#f2f2f2'],
#    ['border', '1px solid #606060'],
#    ['font-size', '24px'],
#    ['padding', '10px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.pop_content': {'style': [['direction', 'ltr'], ['outline', 'none']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.pop_dialog_rtl .pop_content': {'style': [['direction', 'rtl']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.pop_content h2.dialog_title': {'style': [['background', '#6d84b4'],
#    ['border', '1px solid #3b5998'],
#    ['border-bottom', 'none'],
#    ['color', '#fff'],
#    ['font-size', '14px'],
#    ['font-weight', 'bold'],
#    ['margin', '0']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.pop_content h2.secure': {'style': [['background',
#     '#6d84b4 url(/rsrc.php/v2/yu/r/jp8TzrZb6J1.png) 98% no-repeat']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.pop_content h2.loading': {'style': [['background',
#     '#6d84b4 url(/rsrc.php/v2/y-/r/AGUNXgX_Wx3.gif) 98% no-repeat']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.pop_content h2.dialog_loading': {'style': [['background',
#     '#6d84b4 url(/rsrc.php/v2/y-/r/AGUNXgX_Wx3.gif) no-repeat 400px 10px'],
#    ['padding-right', '40px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.pop_content h2 span': {'style': [['display', 'block'],
#    ['padding', '5px 10px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.pop_content .dialog_content': {'style': [['background', '#fff'],
#    ['border', '1px solid #555'],
#    ['border-top-width', '0']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.pop_content .dialog_content.dialog_content_titleless': {'style': [['border-top',
#     '1px solid #555']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.pop_content .dialog_loading,.dialog_loading_shown .dialog_title,.dialog_loading_shown .dialog_content': {'style': [['display',
#     'none']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.dialog_loading_shown .dialog_loading': {'style': [['display', 'block']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.pop_content .dialog_body': {'style': [['padding', '10px'],
#    ['border-bottom', '1px solid #ccc']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.omitDialogFooter .pop_content .dialog_body': {'style': [['border-bottom',
#     '0']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.pop_content .dialog_summary': {'style': [['background', '#f2f2f2'],
#    ['padding', '8px 10px'],
#    ['border-bottom', '1px solid #ccc']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.pop_content .dialog_buttons': {'style': [['background', '#f2f2f2'],
#    ['padding', '8px 10px 8px 10px'],
#    ['position', 'relative']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.pop_content .dialog_buttons_msg': {'style': [['line-height', '17px'],
#    ['padding-top', '4px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.pop_content .dialog_buttons_msg .uiInputLabel': {'style': [['line-height',
#     '14px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.pop_content .dialog_footer': {'style': [['background',
#     '#F2F2F2 none repeat scroll 0%']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.full_bleed .pop_content .dialog_body': {'style': [['padding', '0']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiProfileBlockContent': {'style': [['overflow', 'hidden']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._4jy0,._59pe:focus,._59pe:hover': {'style': [['background',
#     '#f6f7f8 url(/rsrc.php/v2/y1/r/wL6VQj7Ab77.png) repeat-x'],
#    ['-webkit-background-clip', 'padding-box'],
#    ['border', '1px solid'],
#    ['-webkit-border-radius', '2px'],
#    ['-webkit-box-shadow', '0 1px 1px rgba(0,0,0,.05)'],
#    ['-webkit-box-sizing', 'content-box'],
#    ['font-family',
#     "'Helvetica Neue',Helvetica,Arial,'lucida grande',tahoma,verdana,arial,sans-serif"],
#    ['-webkit-font-smoothing', 'antialiased'],
#    ['font-weight', 'bold'],
#    ['padding', '0 8px'],
#    ['position', 'relative'],
#    ['text-align', 'center'],
#    ['vertical-align', 'middle']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._4jy0:before': {'style': [['content', "''"],
#    ['display', 'inline-block'],
#    ['height', '20px'],
#    ['vertical-align', 'middle']],
#   'atRule': '',
#   'mediaQuery': ''},
#  'html ._4jy0:focus': {'style': [['-webkit-box-shadow',
#     '0 0 1px 2px rgba(88,144,255,.75),0 1px 1px rgba(0,0,0,.15)'],
#    ['outline', 'none']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._4jy0 .img': {'style': [['bottom', '1px'],
#    ['position', 'relative'],
#    ['vertical-align', 'middle']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._4jy0 .img.mrs': {'style': [['margin-right', '4px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._4jy0 .img.mls': {'style': [['margin-left', '4px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  'form.async_saving ._4jy0,a.async_saving._4jy0,._4jy0._42fr,._4jy0._42fr:active,._4jy0._42fr:focus,._4jy0._42fr:hover': {'style': [['cursor',
#     'default'],
#    ['opacity', '.5']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._517h,._59pe:focus,._59pe:hover,._517h._42fr:active,._517h._42fr._42fs': {'style': [['border-color',
#     '#cdced0 #c5c6c8 #b6b7b9'],
#    ['color', '#4e5665'],
#    ['text-shadow', '0 1px 0 #fff']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._517h:active,._517h._42fs': {'style': [['border-color', '#c6c7ca']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._517h._42fs': {'style': [['color', '#5890ff']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._4jy1,._4jy2': {'style': [['color', '#fff'],
#    ['text-shadow', '0 -1px 0 rgba(0,0,0,.2)']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._4jy1,._4jy1._42fr:active,._4jy1._42fr._42fs': {'style': [['background-color',
#     '#4e69a2'],
#    ['border-color', '#435a8b #3c5488 #334c83']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._4jy1:active,._4jy1._42fs': {'style': [['background-color', '#4e69a2'],
#    ['border-color', '#2d4373 #314a7f #334c83']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._4jy2,._4jy2._42fr:active,._4jy2._42fr._42fs': {'style': [['background-color',
#     '#6bb933'],
#    ['border-color', '#60a62e #519f18 #409701']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._4jy2:active,._4jy2._42fs': {'style': [['background-color', '#46a800'],
#    ['border-color', '#3a8b00 #3f9700 #419b00']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._59pe,form.async_saving ._59pe,a.async_saving._59pe,._59pe._42fr,._59pe._42fr:active,._59pe._42fr:focus,._59pe._42fr:hover': {'style': [['background',
#     'none'],
#    ['border-color', 'transparent'],
#    ['-webkit-box-shadow', 'none']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._517i,._517i._42fr:active,._517i._42fr._42fs': {'style': [['background-position',
#     '0 0'],
#    ['font-size', '12px'],
#    ['height', '18px'],
#    ['line-height', '18px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._517i:active,._517i._42fs': {'style': [['background-position', '0 -156px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._4jy1._517i,._4jy1._517i._42fr:active,._4jy1._517i._42fr._42fs': {'style': [['background-position',
#     '0 -314px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._4jy1._517i:active,._4jy1._517i._42fs': {'style': [['background-position',
#     '0 -471px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._4jy2._517i,._4jy2._517i._42fr:active,._4jy2._517i._42fr._42fs': {'style': [['background-position',
#     '0 -628px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._4jy2._517i:active,._4jy2._517i._42fs': {'style': [['background-position',
#     '0 -785px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._4jy3,._4jy3._42fr:active,._4jy3._42fr._42fs': {'style': [['background-position',
#     '0 -21px'],
#    ['font-size', '12px'],
#    ['line-height', '22px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._4jy3:active,._4jy3._42fs': {'style': [['background-position', '0 -178px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._4jy1._4jy3,._4jy1._4jy3._42fr:active,._4jy1._4jy3._42fr._42fs': {'style': [['background-position',
#     '0 -335px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._4jy1._4jy3:active,._4jy1._4jy3._42fs': {'style': [['background-position',
#     '0 -492px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._4jy2._4jy3,._4jy2._4jy3._42fr:active,._4jy2._4jy3._42fr._42fs': {'style': [['background-position',
#     '0 -649px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._4jy2._4jy3:active,._4jy2._4jy3._42fs': {'style': [['background-position',
#     '0 -806px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._4jy4,._4jy4._42fr:active,._4jy4._42fr._42fs': {'style': [['background-position',
#     '0 -46px'],
#    ['font-size', '12px'],
#    ['line-height', '26px'],
#    ['padding', '0 10px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._4jy4:active,._4jy4._42fs': {'style': [['background-position', '0 -203px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._4jy1._4jy4,._4jy1._4jy4._42fr:active,._4jy1._4jy4._42fr._42fs': {'style': [['background-position',
#     '0 -360px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._4jy1._4jy4:active,._4jy1._4jy4._42fs': {'style': [['background-position',
#     '0 -517px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._4jy2._4jy4,._4jy2._4jy4._42fr:active,._4jy2._4jy4._42fr._42fs': {'style': [['background-position',
#     '0 -674px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._4jy2._4jy4:active,._4jy2._4jy4._42fs': {'style': [['background-position',
#     '0 -831px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._4jy5,._4jy5._42fr:active,._4jy5._42fr._42fs': {'style': [['background-position',
#     '0 -75px'],
#    ['font-size', '14px'],
#    ['line-height', '34px'],
#    ['padding', '0 16px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._4jy5:active,._4jy5._42fs': {'style': [['background-position', '0 -232px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._4jy1._4jy5,._4jy1._4jy5._42fr:active,._4jy1._4jy5._42fr._42fs': {'style': [['background-position',
#     '0 -389px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._4jy1._4jy5:active,._4jy1._4jy5._42fs': {'style': [['background-position',
#     '0 -546px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._4jy2._4jy5,._4jy2._4jy5._42fr:active,._4jy2._4jy5._42fr._42fs': {'style': [['background-position',
#     '0 -703px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._4jy2._4jy5:active,._4jy2._4jy5._42fs': {'style': [['background-position',
#     '0 -860px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._4jy6,._4jy6._42fr:active,._4jy6._42fr._42fs': {'style': [['background-position',
#     '0 -112px'],
#    ['font-size', '14px'],
#    ['line-height', '42px'],
#    ['padding', '0 24px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._4jy6:active,._4jy6._42fs': {'style': [['background-position', '0 -269px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._4jy1._4jy6,._4jy1._4jy6._42fr:active,._4jy1._4jy6._42fr._42fs': {'style': [['background-position',
#     '0 -426px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._4jy1._4jy6:active,._4jy1._4jy6._42fs': {'style': [['background-position',
#     '0 -583px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._4jy2._4jy6,._4jy2._4jy6._42fr:active,._4jy2._4jy6._42fr._42fs': {'style': [['background-position',
#     '0 -740px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._4jy2._4jy6:active,._4jy2._4jy6._42fs': {'style': [['background-position',
#     '0 -897px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._51xa ._4jy0': {'style': [['-webkit-border-radius', '0'],
#    ['-webkit-box-shadow', 'none'],
#    ['display', 'inline-block'],
#    ['margin', '0!important'],
#    ['margin-left', '-1px!important'],
#    ['position', 'relative'],
#    ['z-index', '1']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._51xa>._4jy0:first-child,._51xa>:first-child ._4jy0': {'style': [['-webkit-border-radius',
#     '2px 0 0 2px'],
#    ['margin-left', '0!important']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._51xa>._4jy0:last-child,._51xa>:last-child ._4jy0': {'style': [['-webkit-border-radius',
#     '0 2px 2px 0']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._51xa ._4jy0._42fr': {'style': [['z-index', '0']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._51xa ._4jy0._4jy1,._51xa ._4jy0._4jy2': {'style': [['z-index', '2']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._51xa ._4jy0:focus': {'style': [['z-index', '3']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._4jy0._52nf': {'style': [['cursor', 'default']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._4jy0._52nd': {'style': [['-webkit-box-shadow', 'none']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._50zz': {'style': [['height', '10px'], ['width', '10px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._50zz._50z-': {'style': [['background-image',
#     'url(/rsrc.php/v2/y2/r/k8z0py7VTRC.png)'],
#    ['background-repeat', 'no-repeat'],
#    ['background-size', 'auto'],
#    ['background-position', '-227px -164px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._50zz._50z-:hover': {'style': [['background-image',
#     'url(/rsrc.php/v2/y2/r/k8z0py7VTRC.png)'],
#    ['background-repeat', 'no-repeat'],
#    ['background-size', 'auto'],
#    ['background-position', '-249px -164px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._50zz._50z-:active,._50zz._42fs': {'style': [['background-image',
#     'url(/rsrc.php/v2/y2/r/k8z0py7VTRC.png)'],
#    ['background-repeat', 'no-repeat'],
#    ['background-size', 'auto'],
#    ['background-position', '-238px -164px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._50zz._50z_': {'style': [['background-image',
#     'url(/rsrc.php/v2/y2/r/k8z0py7VTRC.png)'],
#    ['background-repeat', 'no-repeat'],
#    ['background-size', 'auto'],
#    ['background-position', '-260px -164px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._50zz._50z_:hover': {'style': [['background-image',
#     'url(/rsrc.php/v2/y2/r/k8z0py7VTRC.png)'],
#    ['background-repeat', 'no-repeat'],
#    ['background-size', 'auto'],
#    ['background-position', '-271px -164px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._50-0': {'style': [['height', '12px'], ['width', '12px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._50-0._50z-': {'style': [['background-image',
#     'url(/rsrc.php/v2/y2/r/k8z0py7VTRC.png)'],
#    ['background-repeat', 'no-repeat'],
#    ['background-size', 'auto'],
#    ['background-position', '-294px -175px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._50-0._50z-:hover': {'style': [['background-image',
#     'url(/rsrc.php/v2/y2/r/k8z0py7VTRC.png)'],
#    ['background-repeat', 'no-repeat'],
#    ['background-size', 'auto'],
#    ['background-position', '-320px -175px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._50-0._50z-:active,._50-0._42fs': {'style': [['background-image',
#     'url(/rsrc.php/v2/y2/r/k8z0py7VTRC.png)'],
#    ['background-repeat', 'no-repeat'],
#    ['background-size', 'auto'],
#    ['background-position', '-307px -175px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._50-0._50z_': {'style': [['background-image',
#     'url(/rsrc.php/v2/y2/r/k8z0py7VTRC.png)'],
#    ['background-repeat', 'no-repeat'],
#    ['background-size', 'auto'],
#    ['background-position', '-333px -175px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._50-0._50z_:hover': {'style': [['background-image',
#     'url(/rsrc.php/v2/y2/r/k8z0py7VTRC.png)'],
#    ['background-repeat', 'no-repeat'],
#    ['background-size', 'auto'],
#    ['background-position', '-346px -175px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._5upp': {'style': [['background-color', 'transparent'],
#    ['border', '0 none'],
#    ['cursor', 'pointer'],
#    ['font-size', '0!important'],
#    ['overflow', 'hidden'],
#    ['padding', '0'],
#    ['vertical-align', 'middle']],
#   'atRule': '',
#   'mediaQuery': ''},
#  'html ._5upp:focus': {'style': [['-webkit-box-shadow',
#     '0 0 1px 2px rgba(88,144,255,.75),0 1px 1px rgba(0,0,0,.15)'],
#    ['outline', 'none']],
#   'atRule': '',
#   'mediaQuery': ''},
#  'html ._5upp._5f0v:focus': {'style': [['-webkit-box-shadow', 'none']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.highContrast ._5upp': {'style': [['font-size', '11px!important'],
#    ['height', 'auto'],
#    ['width', 'auto']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._53ii ._53iv': {'style': [['padding', '12px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._53ii ._53ij': {'style': [['border', '0'],
#    ['-webkit-border-radius', '2px'],
#    ['-webkit-box-shadow',
#     '0 0 0 1px rgba(0,0,0,.1),0 1px 10px rgba(0,0,0,.35)']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._53ii ._572u': {'style': [['border-color', '#d3d6db'],
#    ['margin', '0 12px'],
#    ['padding', '8px 0']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._53ii ._53il': {'style': [['padding-top', '18px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._53ii ._53im': {'style': [['padding-right', '18px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._53ii ._53ik': {'style': [['padding-bottom', '18px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._53ii ._53in': {'style': [['padding-left', '18px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._53ii ._53il ._53io': {'style': [['background-image',
#     'url(/rsrc.php/v2/y2/r/k8z0py7VTRC.png)'],
#    ['background-repeat', 'no-repeat'],
#    ['background-size', 'auto'],
#    ['background-position', '-238px -152px'],
#    ['height', '11px'],
#    ['top', '7px'],
#    ['width', '22px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._53ii ._53im ._53io': {'style': [['background-image',
#     'url(/rsrc.php/v2/y2/r/k8z0py7VTRC.png)'],
#    ['background-repeat', 'no-repeat'],
#    ['background-size', 'auto'],
#    ['background-position', '-203px -152px'],
#    ['height', '22px'],
#    ['right', '7px'],
#    ['width', '11px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._53ii ._53ik ._53io': {'style': [['background-image',
#     'url(/rsrc.php/v2/y2/r/k8z0py7VTRC.png)'],
#    ['background-repeat', 'no-repeat'],
#    ['background-size', 'auto'],
#    ['background-position', '-215px -152px'],
#    ['bottom', '7px'],
#    ['height', '11px'],
#    ['width', '22px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._53ii ._53in ._53io': {'style': [['background-image',
#     'url(/rsrc.php/v2/y2/r/k8z0py7VTRC.png)'],
#    ['background-repeat', 'no-repeat'],
#    ['background-size', 'auto'],
#    ['background-position', '-191px -152px'],
#    ['height', '22px'],
#    ['left', '7px'],
#    ['width', '11px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._59s7': {'style': [['-webkit-border-radius', '3px'],
#    ['-webkit-box-shadow',
#     '0 2px 26px rgba(0,0,0,.3),0 0 0 1px rgba(0,0,0,.1)'],
#    ['font-family',
#     "'Helvetica Neue',Helvetica,Arial,'lucida grande',tahoma,verdana,arial,sans-serif"],
#    ['margin', '0 auto 40px'],
#    ['position', 'relative']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._4-hz': {'style': [['background-color', '#fff'],
#    ['-webkit-border-radius', '3px'],
#    ['position', 'relative']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._4-i0': {'style': [['background-color', '#f5f6f7'],
#    ['border-bottom', '1px solid #e5e5e5'],
#    ['-webkit-border-radius', '3px 3px 0 0'],
#    ['color', '#4e5665'],
#    ['font-weight', 'bold'],
#    ['line-height', '19px'],
#    ['padding', '10px 12px'],
#    ['text-shadow', '0 1px 0 #fff']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._4-i0 ._52c9': {'style': [['font-size', '14px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  'div._4-i2': {'style': [['background-color', '#fff'], ['font-size', '14px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._5pfh': {'style': [['overflow-y', 'auto']], 'atRule': '', 'mediaQuery': ''},
#  '._57_a': {'style': [['padding', '12px']], 'atRule': '', 'mediaQuery': ''},
#  '._4-i2:first-child': {'style': [['-webkit-border-radius', '3px 3px 0 0']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._4-i2:last-child': {'style': [['-webkit-border-radius', '0 0 3px 3px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._4-i2:only-child': {'style': [['-webkit-border-radius', '3px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._5a8u': {'style': [['background-color', '#fff'],
#    ['-webkit-border-radius', '0 0 3px 3px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._5a8u ._59jt,._5a8u .uiBoxGray': {'style': [['background', 'transparent'],
#    ['border-top', '1px solid #e9eaed'],
#    ['margin', '0 12px'],
#    ['padding', '12px 0']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._50f3': {'style': [['font-size', '12px'], ['line-height', '16px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._50f4': {'style': [['font-size', '14px'], ['line-height', '18px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._50f5': {'style': [['font-size', '16px'], ['line-height', '20px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._50f6': {'style': [['font-size', '18px'], ['line-height', '22px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._50f7': {'style': [['font-weight', 'bold']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._5kx5': {'style': [['font-weight', 'normal']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._50f8': {'style': [['color', '#898f9c']], 'atRule': '', 'mediaQuery': ''},
#  '._50f9': {'style': [['color', '#4e5665']], 'atRule': '', 'mediaQuery': ''},
#  '.uiButton': {'style': [['cursor', 'pointer'],
#    ['display', 'inline-block'],
#    ['font-size', '11px'],
#    ['font-weight', 'bold'],
#    ['line-height', '13px'],
#    ['padding', '2px 6px'],
#    ['text-align', 'center'],
#    ['text-decoration', 'none'],
#    ['vertical-align', 'top'],
#    ['white-space', 'nowrap']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiButton,.uiButtonSuppressed:active,.uiButtonSuppressed:focus,.uiButtonSuppressed:hover': {'style': [['background-image',
#     'url(/rsrc.php/v2/y2/r/k8z0py7VTRC.png)'],
#    ['background-repeat', 'no-repeat'],
#    ['background-size', 'auto'],
#    ['background-position', '0 -49px'],
#    ['background-color', '#eee'],
#    ['border', '1px solid #999'],
#    ['border-bottom-color', '#888'],
#    ['-webkit-box-shadow', '0 1px 0 rgba(0,0,0,.1)']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiButton + .uiButton': {'style': [['margin-left', '4px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiButton:hover': {'style': [['text-decoration', 'none']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiButton:active,.uiButtonDepressed': {'style': [['background', '#ddd'],
#    ['border-bottom-color', '#999'],
#    ['-webkit-box-shadow', 'inset 0 1px 1px rgba(0,0,0,.2)']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiButton .img': {'style': [['margin-top', '2px'],
#    ['overflow', 'hidden'],
#    ['vertical-align', 'top']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiButtonLarge .img': {'style': [['margin-top', '4px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiButton .customimg': {'style': [['margin-top', '0']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiButtonText,.uiButton input': {'style': [['background', 'none'],
#    ['border', '0'],
#    ['color', '#333'],
#    ['cursor', 'pointer'],
#    ['display', 'inline-block'],
#    ['font-family', "'lucida grande',tahoma,verdana,arial,sans-serif"],
#    ['font-size', '11px'],
#    ['font-weight', 'bold'],
#    ['line-height', '13px'],
#    ['margin', '0'],
#    ['padding', '1px 0 2px'],
#    ['white-space', 'nowrap']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiButtonOverlay,.uiButtonOverlay:hover': {'style': [['-webkit-background-clip',
#     'padding-box'],
#    ['background-color', '#fff'],
#    ['background-color', 'rgba(255,255,255,.8)'],
#    ['background-image', 'none'],
#    ['border-color', '#a5a5a5'],
#    ['border-color', 'rgba(0,0,0,.35)'],
#    ['-webkit-border-radius', '2px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiButtonOverlay:focus,.uiButtonOverlay:active': {'style': [['background-color',
#     '#f9fafc'],
#    ['background-color', 'rgba(249,250,252,.9)'],
#    ['border-color', '#3b5998'],
#    ['border-color', 'rgba(59,89,152,.5)']],
#   'atRule': '',
#   'mediaQuery': ''},
#  'form.async_saving .uiButton.uiButtonOverlay,.uiButtonOverlay.uiButtonDisabled,.uiButtonOverlay.uiButtonDisabled:active,.uiButtonOverlay.uiButtonDisabled:focus,.uiButtonOverlay.uiButtonDisabled:hover': {'style': [['background-color',
#     '#fff'],
#    ['background-color', 'rgba(255,255,255,.8)'],
#    ['border-color', '#c8c8c8'],
#    ['border-color', 'rgba(180,180,180,.8)']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiButtonOverlay.uiButtonDepressed': {'style': [['background-color',
#     'rgba(0,0,0,.05)']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiButtonSpecial': {'style': [['background-image',
#     'url(/rsrc.php/v2/y2/r/k8z0py7VTRC.png)'],
#    ['background-repeat', 'no-repeat'],
#    ['background-size', 'auto'],
#    ['background-position', '0 -98px'],
#    ['background-color', '#69a74e'],
#    ['border-color', '#3b6e22 #3b6e22 #2c5115']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiButtonSpecial:active': {'style': [['background', '#609946'],
#    ['border-bottom-color', '#3b6e22']],
#   'atRule': '',
#   'mediaQuery': ''},
#  'form.async_saving .uiButton.uiButtonSpecial,.uiButtonSpecial.uiButtonDisabled,.uiButtonSpecial.uiButtonDisabled:active,.uiButtonSpecial.uiButtonDisabled:focus,.uiButtonSpecial.uiButtonDisabled:hover': {'style': [['background',
#     '#b4d3a7'],
#    ['border-color', '#9db791']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiButtonConfirm': {'style': [['background-image',
#     'url(/rsrc.php/v2/y2/r/k8z0py7VTRC.png)'],
#    ['background-repeat', 'no-repeat'],
#    ['background-size', 'auto'],
#    ['background-position', '0 0'],
#    ['background-color', '#5b74a8'],
#    ['border-color', '#29447e #29447e #1a356e']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiButtonConfirm:active': {'style': [['background', '#4f6aa3'],
#    ['border-bottom-color', '#29447e']],
#   'atRule': '',
#   'mediaQuery': ''},
#  'form.async_saving .uiButton.uiButtonConfirm,.uiButtonConfirm.uiButtonDisabled,.uiButtonConfirm.uiButtonDisabled:active,.uiButtonConfirm.uiButtonDisabled:focus,.uiButtonConfirm.uiButtonDisabled:hover': {'style': [['background',
#     '#adbad4'],
#    ['border-color', '#94a2bf']],
#   'atRule': '',
#   'mediaQuery': ''},
#  'form.async_saving .uiButton.uiButtonSpecial .uiButtonText,form.async_saving .uiButton.uiButtonSpecial input,form.async_saving .uiButton.uiButtonConfirm .uiButtonText,form.async_saving .uiButton.uiButtonConfirm input,.uiButtonSpecial .uiButtonText,.uiButtonSpecial input,.uiButtonSpecial.uiButtonDisabled .uiButtonText,.uiButtonSpecial.uiButtonDisabled input,.uiButtonConfirm .uiButtonText,.uiButtonConfirm input,.uiButtonConfirm.uiButtonDisabled .uiButtonText,.uiButtonConfirm.uiButtonDisabled input': {'style': [['color',
#     '#fff']],
#   'atRule': '',
#   'mediaQuery': ''},
#  'form.async_saving .uiButton,.uiButtonDisabled,.uiButtonDisabled:active,.uiButtonDisabled:focus,.uiButtonDisabled:hover': {'style': [['background',
#     '#f2f2f2'],
#    ['border-color', '#c8c8c8'],
#    ['-webkit-box-shadow', 'none']],
#   'atRule': '',
#   'mediaQuery': ''},
#  'form.async_saving .uiButton .img,.uiButtonDisabled .img': {'style': [['opacity',
#     '.5']],
#   'atRule': '',
#   'mediaQuery': ''},
#  'form.async_saving .uiButtonText,form.async_saving .uiButton input,.uiButtonDisabled .uiButtonText,.uiButtonDisabled input': {'style': [['color',
#     '#b8b8b8']],
#   'atRule': '',
#   'mediaQuery': ''},
#  'form.async_saving .uiButton,form.async_saving .uiButtonText,form.async_saving .uiButton input,.uiButtonDepressed,.uiButtonDepressed .uiButtonText,.uiButtonDepressed input,.uiButtonDisabled,.uiButtonDisabled .uiButtonText,.uiButtonDisabled input': {'style': [['cursor',
#     'default']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiButtonLarge': {'style': [['height', '19px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiButtonLarge,.uiButtonLarge .uiButtonText,.uiButtonLarge input': {'style': [['font-size',
#     '13px'],
#    ['line-height', '16px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiButtonSuppressed': {'style': [['background', 'none'],
#    ['border-color', 'transparent'],
#    ['-webkit-box-shadow', 'none']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiButtonNoText .img': {'style': [['margin-left', '-1px'],
#    ['margin-right', '-1px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.android .uiButtonText,.android .uiButton input': {'style': [['padding',
#     '3px 0 1px 1px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiBoxGray': {'style': [['background-color', '#f2f2f2'],
#    ['border', '1px solid #ccc']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiBoxDarkgray': {'style': [['color', '#ccc'],
#    ['background-color', '#333'],
#    ['border', '1px solid #666']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiBoxLightblue': {'style': [['background-color', '#edeff4'],
#    ['border', '1px solid #d8dfea']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiBoxRed': {'style': [['background-color', '#ffebe8'],
#    ['border', '1px solid #dd3c10']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiBoxWhite': {'style': [['background-color', '#fff'],
#    ['border', '1px solid #ccc']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiBoxYellow': {'style': [['background-color', '#fff9d7'],
#    ['border', '1px solid #e2c822']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiBoxOverlay': {'style': [['background', 'rgba(255,255,255,.85)'],
#    ['border', '1px solid #3b5998'],
#    ['border', '1px solid rgba(59,89,153,.65)'],
#    ['zoom', '1']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.noborder': {'style': [['border', 'none']], 'atRule': '', 'mediaQuery': ''},
#  '.topborder': {'style': [['border-bottom', 'none'],
#    ['border-left', 'none'],
#    ['border-right', 'none']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.bottomborder': {'style': [['border-left', 'none'],
# ...
#  '._4ki._6-h>li:last-child': {'style': [['padding-right', '0']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiStickyPlaceholderInput': {'style': [['display', 'inline-block'],
#    ['position', 'relative']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiStickyPlaceholderInput input,.uiStickyPlaceholderInput textarea': {'style': [['background-color',
#     'transparent'],
#    ['position', 'relative']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiStickyPlaceholderInput .placeholder': {'style': [['color', '#999'],
#    ['cursor', 'text'],
#    ['display', 'none'],
#    ['height', '100%'],
#    ['left', '0'],
#    ['padding', '4px 0 0 5px'],
#    ['position', 'absolute'],
#    ['top', '0'],
#    ['width', '100%']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiTypeahead .uiStickyPlaceholderInput .placeholder': {'style': [['padding',
#     '3px 0 0 4px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  'div.uiStickyPlaceholderTextarea .placeholder': {'style': [['padding',
#     '6px 0 0 6px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  'div.uiStickyPlaceholderEmptyInput .placeholder': {'style': [['display',
#     'block']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiTypeahead .uiStickyPlaceholderInput': {'style': [['width', '100%']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiClearableTypeahead .selected .uiStickyPlaceholderInput': {'style': [['margin-right',
#     '16px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiHeader h2': {'style': [['color', '#1c2a47'], ['font-size', '16px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiHeader h2 a': {'style': [['color', '#1c2a47']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiHeader h3,.uiHeader h4': {'style': [['color', '#333'],
#    ['font-size', '11px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiHeader h5,.uiHeader h6': {'style': [['color', '#666'],
#    ['font-size', '11px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiHeader .uiHeaderTitle': {'style': [['outline', 'none']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiHeaderWithImage .uiHeaderTop': {'style': [['position', 'relative']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiHeaderWithImage .uiHeaderTitle': {'style': [['padding-left', '22px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiHeaderImage': {'style': [['left', '0'], ['position', 'absolute']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiHeader h2 .uiHeaderImage': {'style': [['top', '2px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiHeaderTopBorder': {'style': [['border-top', '1px solid #aaa'],
#    ['padding-top', '.5em']],
#   'atRule': '',
#   'mediaQuery': ''},
#  'div.uiHeaderTopBorder': {'style': [['margin-left', '0']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiHeaderTopAndBottomBorder': {'style': [['border-bottom',
#     '1px solid #e9e9e9'],
#    ['border-top', '1px solid #aaa'],
#    ['padding', '5px 0']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiHeaderMiddleBorder': {'style': [['border-bottom', '1px solid #ccc'],
#    ['height', '.8em'],
#    ['margin', '.5em 0 1.5em 0'],
#    ['position', 'relative']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiHeaderMiddleBorder .uiHeaderTitle,.uiHeaderMiddleBorder .uiHeaderActions': {'style': [['background-color',
#     '#fff'],
#    ['position', 'absolute'],
#    ['top', '0']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiHeaderMiddleBorder .uiHeaderTitle': {'style': [['left', '0'],
#    ['padding-right', '.5em']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiHeaderMiddleBorder .uiHeaderActions': {'style': [['padding-left', '.5em'],
#    ['right', '0']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiHeaderMiddleBorder .uiButton': {'style': [['margin-top', '-2px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiHeaderBottomBorder': {'style': [['border-bottom', '1px solid #aaa'],
#    ['padding-bottom', '.5em']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiHeaderPage': {'style': [['padding', '6px 0 16px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiHeaderPage .uiHeaderTitle': {'style': [['line-height', '20px'],
#    ['min-height', '20px'],
#    ['padding-bottom', '2px'],
#    ['vertical-align', 'bottom']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiHeaderPage .uiHeaderActions': {'style': [['margin-top', '-1px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiHeaderPage .uiHeaderTop .fsl': {'style': [['margin-top', '3px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiHeaderNav': {'style': [['border-color', '#eee'],
#    ['margin', '8px 0 0 6px'],
#    ['padding', '7px 6px 3px 5px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiHeaderNavEmpty': {'style': [['padding-top', '6px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiHeaderNav h4': {'style': [['color', 'gray']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiHeaderSection,.uiSideHeader': {'style': [['background-color', '#f2f2f2'],
#    ['border-bottom', 'none'],
#    ['border-top', 'solid 1px #e2e2e2'],
#    ['padding', '4px 6px 5px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  'div._3qw': {'style': [['height', 'auto'],
#    ['left', '0'],
#    ['min-height', '100%'],
#    ['position', 'absolute'],
#    ['right', '0'],
#    ['top', '0'],
#    ['z-index', '400']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._31e': {'style': [['position', 'fixed!important'], ['width', '100%']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.webkit ._42w': {'style': [['position', 'absolute'],
#    ['top', '0'],
#    ['visibility', 'hidden'],
#    ['width', '1px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._3qw': {'style': [['background-color', 'rgba(255,255,255,.8)']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._3qx': {'style': [['background-color', 'rgba(0,0,0,.9)']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._3qy': {'style': [['background-color', 'rgba(231,235,243,.92)']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._4-hy': {'style': [['background-color', 'rgba(0,0,0,.4)']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._10': {'style': [['height', '0'],
#    ['left', '0'],
#    ['position', 'fixed'],
#    ['right', '0'],
#    ['top', '0'],
#    ['z-index', '200']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.platform_dialog ._10': {'style': [['position', 'absolute']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._1yv': {'style': [['-webkit-box-shadow',
#     '0 2px 26px rgba(0,0,0,.3),0 0 0 1px rgba(0,0,0,.1)'],
#    ['margin', '0 auto 40px'],
#    ['position', 'relative']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._t': {'style': [['background-color', '#fff'], ['position', 'relative']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._1yw': {'style': [['background-color', '#6d84b4'],
#    ['border', '1px solid #3b5998'],
#    ['border-bottom', '0'],
#    ['color', '#fff'],
#    ['font-size', '14px'],
#    ['font-weight', 'bold']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._13,._14': {'style': [['border-color', '#555'],
#    ['border-style', 'solid'],
#    ['border-width', '0 1px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._13:first-child': {'style': [['border-top-width', '1px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._13:last-child': {'style': [['border-bottom-width', '1px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._14': {'style': [['border-bottom-width', '1px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._r': {'style': [['background-color', '#f2f2f2'],
#    ['font-size', '24px'],
#    ['padding', '10px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiLayer': {'style': [['outline', 'none']], 'atRule': '', 'mediaQuery': ''},
#  '._53ip ._53iv': {'style': [['padding', '15px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._53ip ._53ij': {'style': [['border', '1px solid #8c8c8c'],
#    ['border', '1px solid rgba(0,0,0,.45)'],
#    ['border-bottom', '1px solid #666'],
#    ['-webkit-box-shadow', '0 3px 8px rgba(0,0,0,.3)']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._53ip ._572u': {'style': [['padding', '6px 7px 6px 8px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._53ip ._53il': {'style': [['padding-top', '10px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._53ip ._53im': {'style': [['padding-right', '10px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._53ip ._53ik': {'style': [['padding-bottom', '10px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._53ip ._53in': {'style': [['padding-left', '10px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._53ip ._53il ._53io': {'style': [['background-image',
#     'url(/rsrc.php/v2/y2/r/k8z0py7VTRC.png)'],
#    ['background-repeat', 'no-repeat'],
#    ['background-size', 'auto'],
#    ['background-position', '-312px -152px'],
#    ['height', '9px'],
#    ['top', '2px'],
#    ['width', '16px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._53ip ._53im ._53io': {'style': [['background-image',
#     'url(/rsrc.php/v2/y2/r/k8z0py7VTRC.png)'],
#    ['background-repeat', 'no-repeat'],
#    ['background-size', 'auto'],
#    ['background-position', '-269px -175px'],
#    ['height', '16px'],
#    ['right', '2px'],
#    ['width', '9px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._53ip ._53ik ._53io': {'style': [['background-image',
#     'url(/rsrc.php/v2/y2/r/k8z0py7VTRC.png)'],
#    ['background-repeat', 'no-repeat'],
#    ['background-size', 'auto'],
#    ['background-position', '-261px -152px'],
#    ['bottom', '2px'],
#    ['height', '9px'],
#    ['width', '16px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._53ip ._53ik._kc ._53io': {'style': [['background-image',
#     'url(/rsrc.php/v2/y2/r/k8z0py7VTRC.png)'],
#    ['background-repeat', 'no-repeat'],
#    ['background-size', 'auto'],
#    ['background-position', '-278px -152px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._53ip ._53in ._53io': {'style': [['background-image',
#     'url(/rsrc.php/v2/y2/r/k8z0py7VTRC.png)'],
#    ['background-repeat', 'no-repeat'],
#    ['background-size', 'auto'],
#    ['background-position', '-259px -175px'],
#    ['height', '16px'],
#    ['left', '2px'],
#    ['width', '9px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiContextualDialogFooterLink': {'style': [['background', '#f2f2f2'],
#    ['border-top', '1px solid #e0e0e0'],
#    ['display', 'block'],
#    ['font-weight', 'bold'],
#    ['padding', '7px'],
#    ['text-align', 'center']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiContextualDialogFooterLink:hover': {'style': [['background', '#6d84b4'],
#    ['border-color', '#3b5998'],
#    ['color', '#fff'],
#    ['text-decoration', 'none']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiContextualLayerPositioner': {'style': [['height', '0'],
#    ['position', 'absolute'],
#    ['z-index', '200']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiContextualLayer': {'style': [['position', 'absolute']],
#   'atRule': '',
#   'mediaQuery': ''},
#  'div.uiContextualLayerPositionerFixed': {'style': [['position', 'fixed']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiContextualLayerParent': {'style': [['position', 'relative']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._43q9 ._4cg3': {'style': [['margin-top', '-2px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._43qc ._4cg3': {'style': [['margin-top', '-1px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._43qf ._4cg3': {'style': [['margin-top', '-3px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._43q9 ._43q7': {'style': [['margin', '2px 2px 0 0']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._43qc ._43q7': {'style': [['margin', '1px 1px 0 0']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._43qf ._43q7': {'style': [['margin', '3px 3px 0 0']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._43qm li:last-child': {'style': [['margin-right', '0']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._43q7 a': {'style': [['display', 'block'], ['position', 'relative']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._43q7 .img': {'style': [['vertical-align', 'bottom']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._43qm .showAll': {'style': [['display', 'block']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._43qm ._43qn': {'style': [['border-color', '#7792ba'],
#    ['border-width', '1px 0 0'],
#    ['padding', '3px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._43q9 ._43qn': {'style': [['line-height', '18px'],
#    ['margin', '2px 2px 0 0']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._43qc ._43qn': {'style': [['line-height', '24px'],
#    ['margin', '1px 1px 0 0']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._43qf ._43qn': {'style': [['line-height', '44px'],
#    ['margin', '3px 3px 0 0']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiScaledImageContainer': {'style': [['position', 'relative'],
#    ['overflow', 'hidden']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiScaledImageCentered': {'style': [['background-color', '#f2f2f2'],
#    ['text-align', 'center']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiScaledImageContainer img': {'style': [['height', '100%'],
#    ['min-height', '100%'],
#    ['position', 'relative']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiScaledImageContainer .scaledImageFitWidth': {'style': [['height', 'auto'],
#    ['width', '100%']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiScaledImageContainer .verticallyAligned': {'style': [['min-height', '0'],
#    ['vertical-align', 'middle']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.non-editable-photo': {'style': [['display', 'inline-block'],
#    ['margin', '0 0 110px 20px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._rv': {'style': [['height', '100px'], ['width', '100px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._rw': {'style': [['height', '50px'], ['width', '50px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._s0:only-child': {'style': [['display', 'block']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._54rv': {'style': [['height', '16px'], ['width', '16px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._54ru': {'style': [['height', '32px'], ['width', '32px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._54rt': {'style': [['height', '48px'], ['width', '48px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._54rs': {'style': [['height', '56px'], ['width', '56px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._ry': {'style': [['height', '24px'], ['width', '24px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiP': {'style': [['line-height', '16px']], 'atRule': '', 'mediaQuery': ''},
#  '.uiPLarge': {'style': [['line-height', '18px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.openToggler': {'style': [['z-index', '100']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiToggleFlyout,.toggleTargetClosed,.openToggler .uiToggleFlyout .uiToggleFlyout': {'style': [['display',
#     'none']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.openToggler .uiToggleFlyout,.openToggler .uiToggleFlyout .openToggler .uiToggleFlyout': {'style': [['display',
#     'block']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.hideToggler': {'style': [['border', '0'],
#    ['height', '0'],
#    ['opacity', '0'],
#    ['overflow', 'hidden'],
#    ['padding', '0'],
#    ['pointer-events', 'none'],
#    ['position', 'absolute'],
#    ['width', '0']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._42ef': {'style': [['overflow', 'hidden']], 'atRule': '', 'mediaQuery': ''},
#  '._51mz': {'style': [['border', '0'],
#    ['border-collapse', 'collapse'],
#    ['border-spacing', '0']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._5f0n': {'style': [['table-layout', 'fixed'], ['width', '100%']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiGrid .vTop': {'style': [['vertical-align', 'top']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiGrid .vMid': {'style': [['vertical-align', 'middle']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiGrid .vBot': {'style': [['vertical-align', 'bottom']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiGrid .hLeft': {'style': [['text-align', 'left']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiGrid .hCent': {'style': [['text-align', 'center']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.uiGrid .hRght': {'style': [['text-align', 'right']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._51mx:first-child>._51m-': {'style': [['padding-top', '0']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._51mx:last-child>._51m-': {'style': [['padding-bottom', '0']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._51mz ._51mw': {'style': [['padding-right', '0']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._51mz ._51m-:first-child': {'style': [['padding-left', '0']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '._ohe': {'style': [['float', 'left']], 'atRule': '', 'mediaQuery': ''},
#  '._ohf': {'style': [['float', 'right']], 'atRule': '', 'mediaQuery': ''},
#  '#bootloader_UUsyJ': {'style': [['height', '42px']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '.bootloader_UUsyJ': {'style': [['display', 'block!important']],
#   'atRule': '',
#   'mediaQuery': ''},
#  '': None}

# %% [markdown]
# - convert all values to same format (e.g. color will be all hex) (done)
# - don't convert but additional store the longhand for shorthands (e.g. padding: 10px 20px 20px 10px)
#
# Combine styles:
# - Combine them using the comma seperator if they share >=2 styles
#
# Variables:
# - for all attribute values, if it is repeated >=10 than replace it with a variable
#
# Mixins:
# - If two or more selectors share >=3 properties but different values then created a mixin that shares that has parameters for the different values
#
# Issue: How do you automate naming variables and mixins?

# %%
def colorToHexCode(value):
    try:
        # error is caused with gradients
        if "hsla" in value or "rgba" in value:
            return value

        # seperate hsl or rgb args
        value = value.replace("%", "")
        colors = [int(x) for x in value[value.find("(")+len("("):value.rfind(")")].split(",")]

        # if hsl convert to rgb
        if "hsl" in value:
            h, s, l = colors
            h = h/360
            s = s/100
            l = l/100
            colors = colorsys.hls_to_rgb(h, l, s)
            colors = [int(round(x*255.0)) for x in colors]

        # convert rgb to hexcode
        colors = list(map(lambda color: str(hex(color).split('x')[-1][-2:]).zfill(2), colors))
        colors = "".join(colors)

        return f"#{colors}"
    except:
        return value

# %%
print(colorToHexCode("rgb(3, 252, 198)"))
print(colorToHexCode("hsl(167, 98%, 50%)"))
# Out:
# #03fcc6
# #03fcc6

# %%
mapShortHands = {} # store shorthands here (not implemented yet)

def normalizeStyle(attr, value):
    if "color" in attr:
        if not "#" in value:
           value = colorToHexCode(value)

    return attr, value

for selector in testStyleMap:
    if selector:
        for attr, value in testStyleMap[selector]["style"]:
            attr, value = normalizeStyle(attr, value)

del testStyleMap[""]

# testStyleMap

# %%
# duplicatedStyles = {} # type 1 and 2 duplications

# for selector in testStyleMap:
#     if selector:
#         for attr, value in testStyleMap[selector]["style"]:
#             style = f"{attr}:{value}"
#             if style in duplicatedStyles:
                
# 
# # remove styles with only one selector

# %%
[testStyleMap[key]["style"] for key in testStyleMap if testStyleMap[key]["atRule"] == "" and testStyleMap[key]["mediaQuery"] == ""]
# Out:
# [[['margin', '0'], ['padding', '0']],
#  [['cursor', 'pointer'],
#   ['color', '#666'],
#   ['font-weight', 'bold'],
#   ['vertical-align', 'middle']],
#  [['font-weight', 'normal']],
#  [['border', '1px solid #bdc7d8'],
#   ['margin', '0'],
#   ['padding', '3px'],
#   ['-webkit-appearance', 'none'],
#   ['-webkit-border-radius', '0']],
#  [['max-width', '100%']],
#  [['border', '1px solid #bdc7d8'], ['padding', '2px']],
#  [['padding-bottom', '4px']],
#  [['-webkit-box-shadow', 'none']],
#  [['padding', '0'], ['margin', '0 5px 0 0'], ['vertical-align', 'middle']],
#  [['border', '0'], ['vertical-align', 'middle']],
#  [['border-style', 'solid'],
#   ['border-width', '1px'],
#   ['border-color', '#d9dfea #0e1f5b #0e1f5b #d9dfea'],
#   ['background-color', '#3b5998'],
#   ['color', '#fff'],
#   ['padding', '2px 15px 3px 15px'],
#   ['text-align', 'center']],
#  [['background-color', '#999'],
#   ['border-bottom', '1px solid #000'],
#   ['border-right', '1px solid #666'],
#   ['color', '#fff']],
#  [['background', '#f0f0f0'],
#   ['border-color', '#e7e7e7 #666 #666 #e7e7e7'],
#   ['color', '#000']],
#  [['color', '#999']],
#  [['background',
#    '#fff url(/rsrc.php/v2/yV/r/IJYgcESal33.png) no-repeat left 4px'],
#   ['padding-left', '17px']],
#  [['background', '#fff'],
#   ['color', '#333'],
#   ['line-height', '1.28'],
#   ['margin', '0'],
#   ['padding', '0'],
#   ['text-align', 'left'],
#   ['direction', 'ltr'],
#   ['unicode-bidi', 'embed']],
#  [['font-family', "'lucida grande',tahoma,verdana,arial,sans-serif"],
#   ['font-size', '11px']],
#  [['font-size', '13px'], ['color', '#333'], ['margin', '0'], ['padding', '0']],
#  [['font-size', '14px']],
#  [['font-size', '11px']],
#  [['margin', '1em 0']],
#  [['color', '#3b5998'], ['cursor', 'pointer'], ['text-decoration', 'none']],
#  [['margin', '0']],
#  [['text-decoration', 'underline']],
#  [['border', '0']],
#  [['text-align', 'left']],
#  [['color', '#000']],
#  [['color', '#777']],
#  [['list-style-type', 'none'], ['margin', '0'], ['padding', '0']],
#  [['border-bottom', 'none']],
#  [['background', '#d9d9d9'],
#   ['border-width', '0'],
#   ['color', '#d9d9d9'],
#   ['height', '1px']],
#  [['clear', 'both'],
#   ['content', '"."'],
#   ['display', 'block'],
#   ['font-size', '0'],
#   ['height', '0'],
#   ['line-height', '0'],
#   ['visibility', 'hidden']],
#  [['zoom', '1']],
#  [['word-wrap', 'break-word']],
#  [['display', 'inline-block']],
#  [['overflow', 'hidden'],
#   ['text-overflow', 'ellipsis'],
#   ['white-space', 'nowrap']],
#  [['opacity', '.5']],
#  [['float', 'left']],
#  [['margin-left', 'auto'], ['margin-right', 'auto']],
#  [['display', 'none!important']],
#  [['visibility', 'hidden']],
#  [['clip', 'rect(1px 1px 1px 1px)'],
#   ['clip', 'rect(1px,1px,1px,1px)'],
#   ['height', '1px'],
#   ['overflow', 'hidden'],
#   ['position', 'absolute'],
#   ['width', '1px']],
#  [['direction', 'ltr']],
#  [['direction', 'rtl']],
#  [['text-align', 'left']],
#  [['text-align', 'right']],
#  [['color', '#777']],
#  [['color', '#000']],
#  [['margin', 'auto'], ['width', 'auto']],
#  [['line-height', '20px'], ['width', '540px']],
#  [['padding-right', '10px']],
#  [['background-color', '#fff'], ['clear', 'both'], ['margin-left', '180px']],
#  [['border-top', '0']],
#  [['color', '#737373'],
#   ['font-size', '11px'],
#   ['margin', '0 auto'],
#   ['width', '980px']],
#  [['text-decoration', 'none'], ['white-space', 'nowrap']],
#  [['margin-right', '0']],
#  [['text-decoration', 'underline']],
#  [['border-bottom', '1px solid #ccc'],
#   ['font-size', '1px'],
#   ['height', '8px'],
#   ['margin-bottom', '8px']],
#  [['border', '1px solid #ccc'],
#   ['border-top', 'none'],
#   ['position', 'relative']],
#  [['margin', '0 auto'], ['position', 'relative'], ['zoom', '1']],
#  [['width', '981px']],
#  [['padding-right', '205px']],
#  [['margin', 'auto']],
#  [['padding-top', '0']],
#  [['padding-bottom', '20px']],
#  [['padding-bottom', '0']],
#  [['position', 'fixed!important']],
#  [['position', 'static!important']],
#  [['max-width', '350px'], ['min-width', '275px']],
#  [['max-width', '275px']],
#  [['max-width', '240px']],
#  [['padding', '10px'], ['width', '275px']],
#  [['color', 'gray']],
#  [['margin-left', '4px']],
#  [['margin-right', '10px']],
#  [['width', '350px']],
#  [['margin-top', '78px'], ['position', 'relative']],
#  [['display', 'inline-block'], ['height', '20px']],
#  [['background-color', 'rgba(0,0,0,.5)'],
#   ['left', '0'],
#   ['padding', '5px 0 5px 5px'],
#   ['position', 'absolute'],
#   ['top', '0'],
#   ['width', '99%']],
#  [['color', '#fff'], ['font-size', '11px']],
#  [['border-color', '#d3d6db']],
#  [['left', '-10px'],
#   ['margin-bottom', '-10px'],
#   ['margin-top', '10px'],
#   ['position', 'relative'],
#   ['width', '370px']],
#  [['width', '10000px']],
#  [['padding-top', '46px']],
#  [['color', '#fff']],
#  [['margin-right', '4px']],
#  [['background', '#fff'],
#   ['background', 'rgba(0,0,0,.3)'],
#   ['-webkit-border-radius', '3px'],
#   ['-webkit-box-shadow', '0 1px 1px rgba(0,0,0,.07)'],
#   ['margin', '0 7px -4px -4px'],
#   ['padding', '1px']],
#  [['background-color', '#fff'],
#   ['border', '3px solid #fff'],
#   ['-webkit-border-radius', '2px'],
#   ['display', 'block'],
#   ['height', '100px']],
#  [['bottom', '3px'],
#   ['left', '120px'],
#   ['line-height', '1.2'],
#   ['max-width', '250px'],
#   ['min-height', '37px'],
#   ['position', 'absolute'],
#   ['z-index', '1']],
#  [['max-width', '250px']],
#  [['color', 'rgba(255,255,255,0.68)']],
#  [['background-image', 'url(/rsrc.php/v2/y2/r/k8z0py7VTRC.png)'],
#   ['background-size', 'auto'],
#   ['background-repeat', 'no-repeat'],
#   ['display', 'inline-block'],
#   ['height', '10px'],
#   ['width', '16px']],
#  [['width', '14px'],
#   ['height', '14px'],
#   ['background-position', '-279px -175px']],
#  [['height', '9px'], ['background-position', '-261px -152px']],
#  [['height', '9px'], ['background-position', '-278px -152px']],
#  [['height', '9px'], ['background-position', '-295px -152px']],
#  [['width', '9px'],
#   ['height', '16px'],
#   ['background-position', '-259px -175px']],
#  [['width', '9px'],
#   ['height', '16px'],
#   ['background-position', '-269px -175px']],
#  [['height', '9px'], ['background-position', '-312px -152px']],
#  [['height', '16px'], ['background-position', '-191px -175px']],
#  [['width', '11px'], ['background-position', '-215px -164px']],
#  [['width', '9px'],
#   ['height', '5px'],
#   ['background-position', '-329px -152px']],
#  [['width', '5px'],
#   ['height', '3px'],
#   ['background-position', '-339px -152px']],
#  [['height', '16px'], ['background-position', '-208px -175px']],
#  [['height', '16px'], ['background-position', '-225px -175px']],
#  [['height', '16px'], ['background-position', '-242px -175px']],
#  [['width', '22px'],
#   ['height', '11px'],
#   ['background-position', '-215px -152px']],
#  [['width', '11px'],
#   ['height', '22px'],
#   ['background-position', '-191px -152px']],
#  [['width', '11px'],
#   ['height', '22px'],
#   ['background-position', '-203px -152px']],
#  [['width', '22px'],
#   ['height', '11px'],
#   ['background-position', '-238px -152px']],
#  [['width', '8px'],
#   ['height', '1px'],
#   ['background-position', '-206px -147px']],
#  [['width', '8px'],
#   ['height', '1px'],
#   ['background-position', '-215px -147px']],
#  [['width', '205px'], ['height', '4px'], ['background-position', '0 -147px']],
#  [['width', '12px'],
#   ['height', '12px'],
#   ['background-position', '-294px -175px']],
#  [['width', '12px'],
#   ['height', '12px'],
#   ['background-position', '-307px -175px']],
#  [['width', '12px'],
#   ['height', '12px'],
#   ['background-position', '-320px -175px']],
#  [['width', '12px'],
#   ['height', '12px'],
#   ['background-position', '-333px -175px']],
#  [['width', '12px'],
#   ['height', '12px'],
#   ['background-position', '-346px -175px']],
#  [['width', '10px'], ['background-position', '-227px -164px']],
#  [['width', '10px'], ['background-position', '-238px -164px']],
#  [['width', '10px'], ['background-position', '-249px -164px']],
#  [['width', '10px'], ['background-position', '-260px -164px']],
#  [['width', '10px'], ['background-position', '-271px -164px']],
#  [['width', '500px'], ['height', '48px'], ['background-position', '0 0']],
#  [['width', '500px'], ['height', '48px'], ['background-position', '0 -49px']],
#  [['width', '500px'], ['height', '48px'], ['background-position', '0 -98px']],
#  [['width', '190px'], ['height', '90px'], ['background-position', '0 -152px']],
#  [['cursor', 'pointer'],
#   ['display', 'inline-block'],
#   ['text-decoration', 'none'],
#   ['white-space', 'nowrap']],
#  [['text-decoration', 'none']],
#  [['margin-left', '4px']],
#  [['cursor', 'default']],
#  [['background', '#fff'], ['position', 'relative']],
#  [['overflow', 'hidden'], ['position', 'absolute']],
#  [['display', 'none']],
#  [['outline', 'none']],
#  [['outline', '1px dotted #3b5998'], ['outline-color', 'invert']],
#  [['outline', '5px auto #5b9dd9']],
#  [['outline-color', '#e59700']],
#  [['margin-top', '1px']],
#  [['display', 'block']],
#  [['margin-right', '5px'], ['margin-top', '-1px']],
#  [['margin-right', '8px']],
#  [['margin-right', '10px']],
#  [['background', 'rgba(82,82,82,0.7)'],
#   ['-webkit-border-radius', '8px'],
#   ['padding', '10px']],
#  [['height', '0'],
#   ['left', '0'],
#   ['overflow', 'visible'],
#   ['outline', 'none'],
#   ['position', 'fixed'],
#   ['top', '0'],
#   ['width', '100%'],
#   ['z-index', '200']],
#  [['background-color', 'rgba(252,252,252,.9)'],
#   ['height', '100%'],
#   ['z-index', '400']],
#  [['overflow-x', 'auto'], ['overflow-y', 'scroll']],
#  [['height', 'auto'], ['padding-bottom', '40px']],
#  [['overflow', 'hidden!important']],
#  [['height', '0'],
#   ['overflow', 'visible'],
#   ['width', '465px'],
#   ['margin', '0 auto']],
#  [['background-color', '#f2f2f2'],
#   ['border', '1px solid #606060'],
#   ['font-size', '24px'],
#   ['padding', '10px']],
#  [['direction', 'ltr'], ['outline', 'none']],
#  [['direction', 'rtl']],
#  [['background', '#6d84b4'],
#   ['border', '1px solid #3b5998'],
#   ['border-bottom', 'none'],
#   ['color', '#fff'],
#   ['font-size', '14px'],
#   ['font-weight', 'bold'],
#   ['margin', '0']],
#  [['background',
#    '#6d84b4 url(/rsrc.php/v2/yu/r/jp8TzrZb6J1.png) 98% no-repeat']],
#  [['background',
#    '#6d84b4 url(/rsrc.php/v2/y-/r/AGUNXgX_Wx3.gif) 98% no-repeat']],
#  [['background',
#    '#6d84b4 url(/rsrc.php/v2/y-/r/AGUNXgX_Wx3.gif) no-repeat 400px 10px'],
#   ['padding-right', '40px']],
#  [['display', 'block'], ['padding', '5px 10px']],
#  [['background', '#fff'],
#   ['border', '1px solid #555'],
#   ['border-top-width', '0']],
#  [['border-top', '1px solid #555']],
#  [['display', 'none']],
#  [['display', 'block']],
#  [['padding', '10px'], ['border-bottom', '1px solid #ccc']],
#  [['border-bottom', '0']],
#  [['background', '#f2f2f2'],
#   ['padding', '8px 10px'],
#   ['border-bottom', '1px solid #ccc']],
#  [['background', '#f2f2f2'],
#   ['padding', '8px 10px 8px 10px'],
#   ['position', 'relative']],
#  [['line-height', '17px'], ['padding-top', '4px']],
#  [['line-height', '14px']],
#  [['background', '#F2F2F2 none repeat scroll 0%']],
#  [['padding', '0']],
#  [['overflow', 'hidden']],
#  [['background', '#f6f7f8 url(/rsrc.php/v2/y1/r/wL6VQj7Ab77.png) repeat-x'],
#   ['-webkit-background-clip', 'padding-box'],
#   ['border', '1px solid'],
#   ['-webkit-border-radius', '2px'],
#   ['-webkit-box-shadow', '0 1px 1px rgba(0,0,0,.05)'],
#   ['-webkit-box-sizing', 'content-box'],
#   ['font-family',
#    "'Helvetica Neue',Helvetica,Arial,'lucida grande',tahoma,verdana,arial,sans-serif"],
#   ['-webkit-font-smoothing', 'antialiased'],
#   ['font-weight', 'bold'],
#   ['padding', '0 8px'],
#   ['position', 'relative'],
#   ['text-align', 'center'],
#   ['vertical-align', 'middle']],
#  [['content', "''"],
#   ['display', 'inline-block'],
#   ['height', '20px'],
#   ['vertical-align', 'middle']],
#  [['-webkit-box-shadow',
#    '0 0 1px 2px rgba(88,144,255,.75),0 1px 1px rgba(0,0,0,.15)'],
#   ['outline', 'none']],
#  [['bottom', '1px'], ['position', 'relative'], ['vertical-align', 'middle']],
#  [['margin-right', '4px']],
#  [['margin-left', '4px']],
#  [['cursor', 'default'], ['opacity', '.5']],
#  [['border-color', '#cdced0 #c5c6c8 #b6b7b9'],
#   ['color', '#4e5665'],
#   ['text-shadow', '0 1px 0 #fff']],
#  [['border-color', '#c6c7ca']],
#  [['color', '#5890ff']],
#  [['color', '#fff'], ['text-shadow', '0 -1px 0 rgba(0,0,0,.2)']],
#  [['background-color', '#4e69a2'],
#   ['border-color', '#435a8b #3c5488 #334c83']],
#  [['background-color', '#4e69a2'],
#   ['border-color', '#2d4373 #314a7f #334c83']],
#  [['background-color', '#6bb933'],
#   ['border-color', '#60a62e #519f18 #409701']],
#  [['background-color', '#46a800'],
#   ['border-color', '#3a8b00 #3f9700 #419b00']],
#  [['background', 'none'],
#   ['border-color', 'transparent'],
#   ['-webkit-box-shadow', 'none']],
#  [['background-position', '0 0'],
#   ['font-size', '12px'],
#   ['height', '18px'],
#   ['line-height', '18px']],
#  [['background-position', '0 -156px']],
#  [['background-position', '0 -314px']],
#  [['background-position', '0 -471px']],
#  [['background-position', '0 -628px']],
#  [['background-position', '0 -785px']],
#  [['background-position', '0 -21px'],
#   ['font-size', '12px'],
#   ['line-height', '22px']],
#  [['background-position', '0 -178px']],
#  [['background-position', '0 -335px']],
#  [['background-position', '0 -492px']],
#  [['background-position', '0 -649px']],
#  [['background-position', '0 -806px']],
#  [['background-position', '0 -46px'],
#   ['font-size', '12px'],
#   ['line-height', '26px'],
#   ['padding', '0 10px']],
#  [['background-position', '0 -203px']],
#  [['background-position', '0 -360px']],
#  [['background-position', '0 -517px']],
#  [['background-position', '0 -674px']],
#  [['background-position', '0 -831px']],
#  [['background-position', '0 -75px'],
#   ['font-size', '14px'],
#   ['line-height', '34px'],
#   ['padding', '0 16px']],
#  [['background-position', '0 -232px']],
#  [['background-position', '0 -389px']],
#  [['background-position', '0 -546px']],
#  [['background-position', '0 -703px']],
#  [['background-position', '0 -860px']],
#  [['background-position', '0 -112px'],
#   ['font-size', '14px'],
#   ['line-height', '42px'],
#   ['padding', '0 24px']],
#  [['background-position', '0 -269px']],
#  [['background-position', '0 -426px']],
#  [['background-position', '0 -583px']],
#  [['background-position', '0 -740px']],
#  [['background-position', '0 -897px']],
#  [['-webkit-border-radius', '0'],
#   ['-webkit-box-shadow', 'none'],
#   ['display', 'inline-block'],
#   ['margin', '0!important'],
#   ['margin-left', '-1px!important'],
#   ['position', 'relative'],
#   ['z-index', '1']],
#  [['-webkit-border-radius', '2px 0 0 2px'], ['margin-left', '0!important']],
#  [['-webkit-border-radius', '0 2px 2px 0']],
#  [['z-index', '0']],
#  [['z-index', '2']],
#  [['z-index', '3']],
#  [['cursor', 'default']],
#  [['-webkit-box-shadow', 'none']],
#  [['height', '10px'], ['width', '10px']],
#  [['background-image', 'url(/rsrc.php/v2/y2/r/k8z0py7VTRC.png)'],
#   ['background-repeat', 'no-repeat'],
#   ['background-size', 'auto'],
#   ['background-position', '-227px -164px']],
#  [['background-image', 'url(/rsrc.php/v2/y2/r/k8z0py7VTRC.png)'],
#   ['background-repeat', 'no-repeat'],
#   ['background-size', 'auto'],
#   ['background-position', '-249px -164px']],
#  [['background-image', 'url(/rsrc.php/v2/y2/r/k8z0py7VTRC.png)'],
#   ['background-repeat', 'no-repeat'],
#   ['background-size', 'auto'],
#   ['background-position', '-238px -164px']],
#  [['background-image', 'url(/rsrc.php/v2/y2/r/k8z0py7VTRC.png)'],
#   ['background-repeat', 'no-repeat'],
#   ['background-size', 'auto'],
#   ['background-position', '-260px -164px']],
#  [['background-image', 'url(/rsrc.php/v2/y2/r/k8z0py7VTRC.png)'],
#   ['background-repeat', 'no-repeat'],
#   ['background-size', 'auto'],
#   ['background-position', '-271px -164px']],
#  [['height', '12px'], ['width', '12px']],
#  [['background-image', 'url(/rsrc.php/v2/y2/r/k8z0py7VTRC.png)'],
#   ['background-repeat', 'no-repeat'],
#   ['background-size', 'auto'],
#   ['background-position', '-294px -175px']],
#  [['background-image', 'url(/rsrc.php/v2/y2/r/k8z0py7VTRC.png)'],
#   ['background-repeat', 'no-repeat'],
#   ['background-size', 'auto'],
#   ['background-position', '-320px -175px']],
#  [['background-image', 'url(/rsrc.php/v2/y2/r/k8z0py7VTRC.png)'],
#   ['background-repeat', 'no-repeat'],
#   ['background-size', 'auto'],
#   ['background-position', '-307px -175px']],
#  [['background-image', 'url(/rsrc.php/v2/y2/r/k8z0py7VTRC.png)'],
#   ['background-repeat', 'no-repeat'],
#   ['background-size', 'auto'],
#   ['background-position', '-333px -175px']],
#  [['background-image', 'url(/rsrc.php/v2/y2/r/k8z0py7VTRC.png)'],
#   ['background-repeat', 'no-repeat'],
#   ['background-size', 'auto'],
#   ['background-position', '-346px -175px']],
#  [['background-color', 'transparent'],
#   ['border', '0 none'],
#   ['cursor', 'pointer'],
#   ['font-size', '0!important'],
#   ['overflow', 'hidden'],
#   ['padding', '0'],
#   ['vertical-align', 'middle']],
#  [['-webkit-box-shadow',
#    '0 0 1px 2px rgba(88,144,255,.75),0 1px 1px rgba(0,0,0,.15)'],
#   ['outline', 'none']],
#  [['-webkit-box-shadow', 'none']],
#  [['font-size', '11px!important'], ['height', 'auto'], ['width', 'auto']],
#  [['padding', '12px']],
#  [['border', '0'],
#   ['-webkit-border-radius', '2px'],
#   ['-webkit-box-shadow',
#    '0 0 0 1px rgba(0,0,0,.1),0 1px 10px rgba(0,0,0,.35)']],
#  [['border-color', '#d3d6db'], ['margin', '0 12px'], ['padding', '8px 0']],
#  [['padding-top', '18px']],
#  [['padding-right', '18px']],
#  [['padding-bottom', '18px']],
#  [['padding-left', '18px']],
#  [['background-image', 'url(/rsrc.php/v2/y2/r/k8z0py7VTRC.png)'],
#   ['background-repeat', 'no-repeat'],
#   ['background-size', 'auto'],
#   ['background-position', '-238px -152px'],
#   ['height', '11px'],
#   ['top', '7px'],
#   ['width', '22px']],
#  [['background-image', 'url(/rsrc.php/v2/y2/r/k8z0py7VTRC.png)'],
#   ['background-repeat', 'no-repeat'],
#   ['background-size', 'auto'],
#   ['background-position', '-203px -152px'],
#   ['height', '22px'],
#   ['right', '7px'],
#   ['width', '11px']],
#  [['background-image', 'url(/rsrc.php/v2/y2/r/k8z0py7VTRC.png)'],
#   ['background-repeat', 'no-repeat'],
#   ['background-size', 'auto'],
#   ['background-position', '-215px -152px'],
#   ['bottom', '7px'],
#   ['height', '11px'],
#   ['width', '22px']],
#  [['background-image', 'url(/rsrc.php/v2/y2/r/k8z0py7VTRC.png)'],
#   ['background-repeat', 'no-repeat'],
#   ['background-size', 'auto'],
#   ['background-position', '-191px -152px'],
#   ['height', '22px'],
#   ['left', '7px'],
#   ['width', '11px']],
#  [['-webkit-border-radius', '3px'],
#   ['-webkit-box-shadow', '0 2px 26px rgba(0,0,0,.3),0 0 0 1px rgba(0,0,0,.1)'],
#   ['font-family',
#    "'Helvetica Neue',Helvetica,Arial,'lucida grande',tahoma,verdana,arial,sans-serif"],
#   ['margin', '0 auto 40px'],
#   ['position', 'relative']],
#  [['background-color', '#fff'],
#   ['-webkit-border-radius', '3px'],
#   ['position', 'relative']],
#  [['background-color', '#f5f6f7'],
#   ['border-bottom', '1px solid #e5e5e5'],
#   ['-webkit-border-radius', '3px 3px 0 0'],
#   ['color', '#4e5665'],
#   ['font-weight', 'bold'],
#   ['line-height', '19px'],
#   ['padding', '10px 12px'],
#   ['text-shadow', '0 1px 0 #fff']],
#  [['font-size', '14px']],
#  [['background-color', '#fff'], ['font-size', '14px']],
#  [['overflow-y', 'auto']],
#  [['padding', '12px']],
#  [['-webkit-border-radius', '3px 3px 0 0']],
#  [['-webkit-border-radius', '0 0 3px 3px']],
#  [['-webkit-border-radius', '3px']],
#  [['background-color', '#fff'], ['-webkit-border-radius', '0 0 3px 3px']],
#  [['background', 'transparent'],
#   ['border-top', '1px solid #e9eaed'],
#   ['margin', '0 12px'],
#   ['padding', '12px 0']],
#  [['font-size', '12px'], ['line-height', '16px']],
#  [['font-size', '14px'], ['line-height', '18px']],
#  [['font-size', '16px'], ['line-height', '20px']],
#  [['font-size', '18px'], ['line-height', '22px']],
#  [['font-weight', 'bold']],
#  [['font-weight', 'normal']],
#  [['color', '#898f9c']],
#  [['color', '#4e5665']],
#  [['cursor', 'pointer'],
#   ['display', 'inline-block'],
#   ['font-size', '11px'],
#   ['font-weight', 'bold'],
#   ['line-height', '13px'],
#   ['padding', '2px 6px'],
#   ['text-align', 'center'],
#   ['text-decoration', 'none'],
#   ['vertical-align', 'top'],
#   ['white-space', 'nowrap']],
#  [['background-image', 'url(/rsrc.php/v2/y2/r/k8z0py7VTRC.png)'],
#   ['background-repeat', 'no-repeat'],
#   ['background-size', 'auto'],
#   ['background-position', '0 -49px'],
#   ['background-color', '#eee'],
#   ['border', '1px solid #999'],
#   ['border-bottom-color', '#888'],
#   ['-webkit-box-shadow', '0 1px 0 rgba(0,0,0,.1)']],
#  [['margin-left', '4px']],
#  [['text-decoration', 'none']],
#  [['background', '#ddd'],
#   ['border-bottom-color', '#999'],
#   ['-webkit-box-shadow', 'inset 0 1px 1px rgba(0,0,0,.2)']],
#  [['margin-top', '2px'], ['overflow', 'hidden'], ['vertical-align', 'top']],
#  [['margin-top', '4px']],
#  [['margin-top', '0']],
#  [['background', 'none'],
#   ['border', '0'],
#   ['color', '#333'],
#   ['cursor', 'pointer'],
#   ['display', 'inline-block'],
#   ['font-family', "'lucida grande',tahoma,verdana,arial,sans-serif"],
#   ['font-size', '11px'],
#   ['font-weight', 'bold'],
#   ['line-height', '13px'],
#   ['margin', '0'],
#   ['padding', '1px 0 2px'],
#   ['white-space', 'nowrap']],
#  [['-webkit-background-clip', 'padding-box'],
#   ['background-color', '#fff'],
#   ['background-color', 'rgba(255,255,255,.8)'],
#   ['background-image', 'none'],
#   ['border-color', '#a5a5a5'],
#   ['border-color', 'rgba(0,0,0,.35)'],
#   ['-webkit-border-radius', '2px']],
#  [['background-color', '#f9fafc'],
#   ['background-color', 'rgba(249,250,252,.9)'],
#   ['border-color', '#3b5998'],
#   ['border-color', 'rgba(59,89,152,.5)']],
#  [['background-color', '#fff'],
#   ['background-color', 'rgba(255,255,255,.8)'],
#   ['border-color', '#c8c8c8'],
#   ['border-color', 'rgba(180,180,180,.8)']],
#  [['background-color', 'rgba(0,0,0,.05)']],
#  [['background-image', 'url(/rsrc.php/v2/y2/r/k8z0py7VTRC.png)'],
#   ['background-repeat', 'no-repeat'],
#   ['background-size', 'auto'],
#   ['background-position', '0 -98px'],
#   ['background-color', '#69a74e'],
#   ['border-color', '#3b6e22 #3b6e22 #2c5115']],
#  [['background', '#609946'], ['border-bottom-color', '#3b6e22']],
#  [['background', '#b4d3a7'], ['border-color', '#9db791']],
#  [['background-image', 'url(/rsrc.php/v2/y2/r/k8z0py7VTRC.png)'],
#   ['background-repeat', 'no-repeat'],
#   ['background-size', 'auto'],
#   ['background-position', '0 0'],
#   ['background-color', '#5b74a8'],
#   ['border-color', '#29447e #29447e #1a356e']],
#  [['background', '#4f6aa3'], ['border-bottom-color', '#29447e']],
#  [['background', '#adbad4'], ['border-color', '#94a2bf']],
#  [['color', '#fff']],
#  [['background', '#f2f2f2'],
#   ['border-color', '#c8c8c8'],
#   ['-webkit-box-shadow', 'none']],
#  [['opacity', '.5']],
#  [['color', '#b8b8b8']],
#  [['cursor', 'default']],
#  [['height', '19px']],
#  [['font-size', '13px'], ['line-height', '16px']],
#  [['background', 'none'],
#   ['border-color', 'transparent'],
#   ['-webkit-box-shadow', 'none']],
#  [['margin-left', '-1px'], ['margin-right', '-1px']],
#  [['padding', '3px 0 1px 1px']],
#  [['background-color', '#f2f2f2'], ['border', '1px solid #ccc']],
#  [['color', '#ccc'],
#   ['background-color', '#333'],
#   ['border', '1px solid #666']],
#  [['background-color', '#edeff4'], ['border', '1px solid #d8dfea']],
#  [['background-color', '#ffebe8'], ['border', '1px solid #dd3c10']],
#  [['background-color', '#fff'], ['border', '1px solid #ccc']],
#  [['background-color', '#fff9d7'], ['border', '1px solid #e2c822']],
#  [['background', 'rgba(255,255,255,.85)'],
#   ['border', '1px solid #3b5998'],
#   ['border', '1px solid rgba(59,89,153,.65)'],
#   ['zoom', '1']],
#  [['border', 'none']],
#  [['border-bottom', 'none'],
#   ['border-left', 'none'],
#   ['border-right', 'none']],
#  [['border-left', 'none'], ['border-right', 'none'], ['border-top', 'none']],
#  [['border-style', 'dashed']],
#  [['display', 'inline-block'],
#   ['padding-left', '21px'],
#   ['position', 'relative']],
#  [['vertical-align', 'baseline']],
#  [['left', '0'],
#   ['position', 'absolute'],
#   ['top', '-1px'],
#   ['vertical-align', 'middle']],
#  [['-ms-high-contrast-adjust', 'none'], ['_overflow', 'hidden']],
#  [['left', '-999999px'], ['position', 'absolute']],
#  [['float', 'left']],
#  [['float', 'right']],
#  [['color', '#6d84b4']],
#  [['color', 'gray']],
#  [['color', '#141823']],
#  [['padding', '5px']],
#  [['padding', '10px']],
#  [['padding', '20px']],
#  [['padding-top', '5px']],
#  [['padding-top', '10px']],
#  [['padding-top', '20px']],
#  [['padding-right', '5px']],
#  [['padding-right', '10px']],
#  [['padding-right', '20px']],
#  [['padding-bottom', '5px']],
#  [['padding-bottom', '10px']],
#  [['padding-bottom', '20px']],
#  [['padding-left', '5px']],
#  [['padding-left', '10px']],
#  [['padding-left', '20px']],
#  [['padding-left', '5px'], ['padding-right', '5px']],
#  [['padding-left', '10px'], ['padding-right', '10px']],
#  [['padding-left', '20px'], ['padding-right', '20px']],
#  [['padding-top', '5px'], ['padding-bottom', '5px']],
#  [['padding-top', '10px'], ['padding-bottom', '10px']],
#  [['padding-top', '20px'], ['padding-bottom', '20px']],
#  [['margin', '5px']],
#  [['margin', '10px']],
#  [['margin', '20px']],
#  [['margin-top', '5px']],
#  [['margin-top', '10px']],
#  [['margin-top', '20px']],
#  [['margin-right', '5px']],
#  [['margin-right', '10px']],
#  [['margin-right', '20px']],
#  [['margin-bottom', '5px']],
#  [['margin-bottom', '10px']],
#  [['margin-bottom', '20px']],
#  [['margin-left', '5px']],
#  [['margin-left', '10px']],
#  [['margin-left', '20px']],
#  [['margin-left', '5px'], ['margin-right', '5px']],
#  [['margin-left', '10px'], ['margin-right', '10px']],
#  [['margin-left', '20px'], ['margin-right', '20px']],
#  [['margin-top', '5px'], ['margin-bottom', '5px']],
#  [['margin-top', '10px'], ['margin-bottom', '10px']],
#  [['margin-top', '20px'], ['margin-bottom', '20px']],
#  [['font-size', '9px']],
#  [['font-size', '11px']],
#  [['font-size', '13px']],
#  [['font-size', '16px']],
#  [['font-size', '18px']],
#  [['font-weight', 'normal']],
#  [['font-weight', 'bold']],
#  [['color', '#333']],
#  [['color', 'gray']],
#  [['color', '#fff']],
#  [['border-width', '0 0 0 1px'], ['display', 'inline-block']],
#  [['border-width', '1px 0 0 0']],
#  [['vertical-align', 'top']],
#  [['vertical-align', 'middle']],
#  [['vertical-align', 'bottom']],
#  [['border-width', '0']],
#  [['border-color', '#e9e9e9'], ['border-style', 'solid']],
#  [['border-color', '#ccc'], ['border-style', 'solid']],
#  [['border-color', '#aaa'], ['border-style', 'solid']],
#  [['color', '#3b5998'],
#   ['list-style-type', 'square'],
#   ['margin-left', '12px']],
#  [['padding-left', '20px'], ['padding-right', '20px']],
#  [['padding-left', '5px'], ['padding-right', '5px']],
#  [['padding-left', '10px'], ['padding-right', '10px']],
#  [['padding-right', '0']],
#  [['padding-top', '5px'], ['padding-bottom', '5px']],
#  [['padding-top', '10px'], ['padding-bottom', '10px']],
#  [['padding-top', '20px'], ['padding-bottom', '20px']],
#  [['padding-bottom', '0']],
#  [['padding-top', '0']],
#  [['padding-bottom', '0']],
#  [['padding-left', '0']],
#  [['padding-right', '0']],
#  [['display', 'inline-block'], ['position', 'relative']],
#  [['background-color', 'transparent'], ['position', 'relative']],
#  [['color', '#999'],
#   ['cursor', 'text'],
#   ['display', 'none'],
#   ['height', '100%'],
#   ['left', '0'],
#   ['padding', '4px 0 0 5px'],
#   ['position', 'absolute'],
#   ['top', '0'],
#   ['width', '100%']],
#  [['padding', '3px 0 0 4px']],
#  [['padding', '6px 0 0 6px']],
#  [['display', 'block']],
#  [['width', '100%']],
#  [['margin-right', '16px']],
#  [['color', '#1c2a47'], ['font-size', '16px']],
#  [['color', '#1c2a47']],
#  [['color', '#333'], ['font-size', '11px']],
#  [['color', '#666'], ['font-size', '11px']],
#  [['outline', 'none']],
#  [['position', 'relative']],
#  [['padding-left', '22px']],
#  [['left', '0'], ['position', 'absolute']],
#  [['top', '2px']],
#  [['border-top', '1px solid #aaa'], ['padding-top', '.5em']],
#  [['margin-left', '0']],
#  [['border-bottom', '1px solid #e9e9e9'],
#   ['border-top', '1px solid #aaa'],
#   ['padding', '5px 0']],
#  [['border-bottom', '1px solid #ccc'],
#   ['height', '.8em'],
#   ['margin', '.5em 0 1.5em 0'],
#   ['position', 'relative']],
#  [['background-color', '#fff'], ['position', 'absolute'], ['top', '0']],
#  [['left', '0'], ['padding-right', '.5em']],
#  [['padding-left', '.5em'], ['right', '0']],
#  [['margin-top', '-2px']],
#  [['border-bottom', '1px solid #aaa'], ['padding-bottom', '.5em']],
#  [['padding', '6px 0 16px']],
#  [['line-height', '20px'],
#   ['min-height', '20px'],
#   ['padding-bottom', '2px'],
#   ['vertical-align', 'bottom']],
#  [['margin-top', '-1px']],
#  [['margin-top', '3px']],
#  [['border-color', '#eee'],
#   ['margin', '8px 0 0 6px'],
#   ['padding', '7px 6px 3px 5px']],
#  [['padding-top', '6px']],
#  [['color', 'gray']],
#  [['background-color', '#f2f2f2'],
#   ['border-bottom', 'none'],
#   ['border-top', 'solid 1px #e2e2e2'],
#   ['padding', '4px 6px 5px']],
#  [['height', 'auto'],
#   ['left', '0'],
#   ['min-height', '100%'],
#   ['position', 'absolute'],
#   ['right', '0'],
#   ['top', '0'],
#   ['z-index', '400']],
#  [['position', 'fixed!important'], ['width', '100%']],
#  [['position', 'absolute'],
#   ['top', '0'],
#   ['visibility', 'hidden'],
#   ['width', '1px']],
#  [['background-color', 'rgba(255,255,255,.8)']],
#  [['background-color', 'rgba(0,0,0,.9)']],
#  [['background-color', 'rgba(231,235,243,.92)']],
#  [['background-color', 'rgba(0,0,0,.4)']],
#  [['height', '0'],
#   ['left', '0'],
#   ['position', 'fixed'],
#   ['right', '0'],
#   ['top', '0'],
#   ['z-index', '200']],
#  [['position', 'absolute']],
#  [['-webkit-box-shadow', '0 2px 26px rgba(0,0,0,.3),0 0 0 1px rgba(0,0,0,.1)'],
#   ['margin', '0 auto 40px'],
#   ['position', 'relative']],
#  [['background-color', '#fff'], ['position', 'relative']],
#  [['background-color', '#6d84b4'],
#   ['border', '1px solid #3b5998'],
#   ['border-bottom', '0'],
#   ['color', '#fff'],
#   ['font-size', '14px'],
#   ['font-weight', 'bold']],
#  [['border-color', '#555'],
#   ['border-style', 'solid'],
#   ['border-width', '0 1px']],
#  [['border-top-width', '1px']],
#  [['border-bottom-width', '1px']],
#  [['border-bottom-width', '1px']],
#  [['background-color', '#f2f2f2'], ['font-size', '24px'], ['padding', '10px']],
#  [['outline', 'none']],
#  [['padding', '15px']],
#  [['border', '1px solid #8c8c8c'],
#   ['border', '1px solid rgba(0,0,0,.45)'],
#   ['border-bottom', '1px solid #666'],
#   ['-webkit-box-shadow', '0 3px 8px rgba(0,0,0,.3)']],
#  [['padding', '6px 7px 6px 8px']],
#  [['padding-top', '10px']],
#  [['padding-right', '10px']],
#  [['padding-bottom', '10px']],
#  [['padding-left', '10px']],
#  [['background-image', 'url(/rsrc.php/v2/y2/r/k8z0py7VTRC.png)'],
#   ['background-repeat', 'no-repeat'],
#   ['background-size', 'auto'],
#   ['background-position', '-312px -152px'],
#   ['height', '9px'],
#   ['top', '2px'],
#   ['width', '16px']],
#  [['background-image', 'url(/rsrc.php/v2/y2/r/k8z0py7VTRC.png)'],
#   ['background-repeat', 'no-repeat'],
#   ['background-size', 'auto'],
#   ['background-position', '-269px -175px'],
#   ['height', '16px'],
#   ['right', '2px'],
#   ['width', '9px']],
#  [['background-image', 'url(/rsrc.php/v2/y2/r/k8z0py7VTRC.png)'],
#   ['background-repeat', 'no-repeat'],
#   ['background-size', 'auto'],
#   ['background-position', '-261px -152px'],
#   ['bottom', '2px'],
#   ['height', '9px'],
#   ['width', '16px']],
#  [['background-image', 'url(/rsrc.php/v2/y2/r/k8z0py7VTRC.png)'],
#   ['background-repeat', 'no-repeat'],
#   ['background-size', 'auto'],
#   ['background-position', '-278px -152px']],
#  [['background-image', 'url(/rsrc.php/v2/y2/r/k8z0py7VTRC.png)'],
#   ['background-repeat', 'no-repeat'],
#   ['background-size', 'auto'],
#   ['background-position', '-259px -175px'],
#   ['height', '16px'],
#   ['left', '2px'],
#   ['width', '9px']],
#  [['background', '#f2f2f2'],
#   ['border-top', '1px solid #e0e0e0'],
#   ['display', 'block'],
#   ['font-weight', 'bold'],
#   ['padding', '7px'],
#   ['text-align', 'center']],
#  [['background', '#6d84b4'],
#   ['border-color', '#3b5998'],
#   ['color', '#fff'],
#   ['text-decoration', 'none']],
#  [['height', '0'], ['position', 'absolute'], ['z-index', '200']],
#  [['position', 'absolute']],
#  [['position', 'fixed']],
#  [['position', 'relative']],
#  [['margin-top', '-2px']],
#  [['margin-top', '-1px']],
#  [['margin-top', '-3px']],
#  [['margin', '2px 2px 0 0']],
#  [['margin', '1px 1px 0 0']],
#  [['margin', '3px 3px 0 0']],
#  [['margin-right', '0']],
#  [['display', 'block'], ['position', 'relative']],
#  [['vertical-align', 'bottom']],
#  [['display', 'block']],
#  [['border-color', '#7792ba'],
#   ['border-width', '1px 0 0'],
#   ['padding', '3px']],
#  [['line-height', '18px'], ['margin', '2px 2px 0 0']],
#  [['line-height', '24px'], ['margin', '1px 1px 0 0']],
#  [['line-height', '44px'], ['margin', '3px 3px 0 0']],
#  [['position', 'relative'], ['overflow', 'hidden']],
#  [['background-color', '#f2f2f2'], ['text-align', 'center']],
#  [['height', '100%'], ['min-height', '100%'], ['position', 'relative']],
#  [['height', 'auto'], ['width', '100%']],
#  [['min-height', '0'], ['vertical-align', 'middle']],
#  [['display', 'inline-block'], ['margin', '0 0 110px 20px']],
#  [['height', '100px'], ['width', '100px']],
#  [['height', '50px'], ['width', '50px']],
#  [['display', 'block']],
#  [['height', '16px'], ['width', '16px']],
#  [['height', '32px'], ['width', '32px']],
#  [['height', '48px'], ['width', '48px']],
#  [['height', '56px'], ['width', '56px']],
#  [['height', '24px'], ['width', '24px']],
#  [['line-height', '16px']],
#  [['line-height', '18px']],
#  [['z-index', '100']],
#  [['display', 'none']],
#  [['display', 'block']],
#  [['border', '0'],
#   ['height', '0'],
#   ['opacity', '0'],
#   ['overflow', 'hidden'],
#   ['padding', '0'],
#   ['pointer-events', 'none'],
#   ['position', 'absolute'],
#   ['width', '0']],
#  [['overflow', 'hidden']],
#  [['border', '0'], ['border-collapse', 'collapse'], ['border-spacing', '0']],
#  [['table-layout', 'fixed'], ['width', '100%']],
#  [['vertical-align', 'top']],
#  [['vertical-align', 'middle']],
#  [['vertical-align', 'bottom']],
#  [['text-align', 'left']],
#  [['text-align', 'center']],
#  [['text-align', 'right']],
#  [['padding-top', '0']],
#  [['padding-bottom', '0']],
#  [['padding-right', '0']],
#  [['padding-left', '0']],
#  [['float', 'left']],
#  [['float', 'right']],
#  [['height', '42px']],
#  [['display', 'block!important']]]

# %%
def getFileByExtension(extension_name):
    if os.path.isdir("minified-dataset"):
        shutil.rmtree("minified-dataset", ignore_errors=True)

    os.mkdir("minified-dataset")
    
    valid_files = []

    for filePath, dirs, files in os.walk("original-dataset"):
        minifiedStartingPath = filePath.replace("original-dataset", "")

        for directory in dirs:
            os.mkdir(f"minified-dataset\\{minifiedStartingPath}\\{directory}")

        for file in files:
            if file[-len(extension_name):] == extension_name:
                valid_files.append((os.path.join(filePath, file), 
                    os.path.join(f"minified-dataset{minifiedStartingPath}", file)))

                with open(os.path.join(filePath, file), "rb") as f:
                    file_text = f.read().decode(errors="replace")

                with open(f"minified-dataset\\{minifiedStartingPath}\\{file}", "w") as f:
                    f.write(rcssmin.cssmin(file_text))

    return valid_files

# %%
css_files = getFileByExtension(".css")
# print(css_files)
print(len(css_files))
css_files[0]
# Out:
# 552
# ('original-dataset\\9292.nl\\index_files\\print.min.css',
#  'minified-dataset\\9292.nl\\index_files\\print.min.css')

# %%
style_sheets = []

for i, (css_file_path, css_minified_path) in enumerate(css_files):
    with open(css_minified_path, "rb") as file:
            minified_css = file.read().decode(errors="replace")

    style_sheets.append(getSelectorStyleMap(minified_css))
    print(f"File: {i+1} / {len(css_files)}", end="\r")

# style_sheets
# Out:
# File: 552 / 552
