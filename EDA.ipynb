# %%
import os
import pandas
from pandas_profiling import ProfileReport

# %%
for x, y, z in os.walk("./original-dataset"):
  print("x", y)
# Out:
# x ['9292.nl', 'About.com', 'Alibaba', 'Amazon.ca', 'Apple.com', 'BBC', 'BeckerElectric', 'CNN', 'Craigslist', 'Ebay', 'EmployeeSolutions', 'Equus', 'Facebook', 'Github', 'GlobalTVBC', 'Gmail-fixed', 'Gmail-original', 'ICSE12', 'Igloo', 'Imgur', 'Lenovo', 'MEC', 'Microsoft', 'MSN', 'MSNWeather', 'Outlook.com', 'Paypal', 'Phormer', 'Pinterest', 'ProToolsExpress', 'Reddit', 'Rijksmuseum.nl', 'Staples', 'SyncCreative', 'Tumblr.com', 'Twitter', 'UniqueVanities', 'Vimeo.com', 'Wordpress.org', 'YahooMail', 'YouTube']
# x ['index_files', 'results']
# x []
# x ['run1', 'run2']
# x []
# x []
# x ['css', 'results']
# x []
# x ['run1', 'run2']
# x []
# x []
# x ['css', 'results']
# x []
# x ['run1', 'run2']
# x []
# x []
# x ['css', 'results']
# x []
# x ['run1', 'run2']
# x []
# x []
# x ['css', 'results']
# x []
# x ['run1', 'run2']
# x []
# x []
# x ['css', 'results']
# x []
# x ['run1', 'run2']
# x []
# x []
# x ['index_files', 'results']
# x []
# x ['run1', 'run2']
# x []
# x []
# ...
